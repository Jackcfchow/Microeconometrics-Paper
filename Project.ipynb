# %% [markdown]
# This notebook contains my replication of the results from the following paper:
#
#     Bleakley, Hoyt, and Chin, Aimee. 2010. Age at arrival, English proficiency, and social assimilation among US immigrants. American Economic Journal: Applied Economics, 2(1), 165-92.

# %% [markdown]
# Downloading and viewing this notebook:
#
# -The best way to view this notebook is by downloading it and the repository it is located in from //GitHub//. Other viewing options like MyBinder or NBViewer may have issues with displaying images or coloring of certain parts (missing images can be viewed in the folder //files// on GitHub).
#
# -The original paper, as well as the data and codes provided by the authors can be accessed here: https://www.aeaweb.org/articles?id=10.1257/app.2.1.165

# %%
#importing packages
import numpy as np
import pandas as pd
from statsmodels.formula.api import wls
from auxiliary import *
from auxiliary2 import *
#setting up dataframes
df_ind1 = pd.read_csv( 'data/p00use_mf_indiv1.csv')
df_ind2 = pd.read_csv( 'data/p00use_mf_indiv2.csv')
df_ind = df_ind1.append(df_ind2)
df_mat = pd.read_csv( 'data/p00use_mf_matched_with_spouse.csv')

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
# <ul class="toc-item">
#     <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction-1">1. Introduction</a></span></li>
#         <li><span><a href="#2.-Theoretical-Background-and-Data-Description" data-toc-modified-id="##2.-Theoretical-Background-and-Data-Description-2">2. Theoretical Background and Data Description</a></span><ul class="toc-item">
#         <li><span><a href="#2.1-Theoretical-Background" data-toc-modified-id="2.1-Theoretical-Background-2.1">2.1 Theoretical Background</a></span></li>
#         <li><span><a href="#2.2-Data-Description" data-toc-modified-id="2.2-Data-Description-2.2">2.2 Data Description</a></span></li></ul></li>
#     <li><span><a href="#3.-Identification-and-Empirical-Strategy" data-toc-modified-id="3.-Identification-and-Empirical-Strategy-3">3. Identification and Empirical Strategy</a></span></li>
#     <li><span><a href="#4.-Conceptual-issues-in-the-benchmark" data-toc-modified-id="#4.-Conceptual-issues-in-the-benchmark-4">4. Conceptual issues in the benchmark</a></span><ul class="toc-item">
#         <li><span><a href="#4.1-Social-outcome-and-social-assimilation" data-toc-modified-id="4.1-Social-outcome-and-social-assimilation-4.1">4.1 Social outcome and social assimilation</a></span></li>
#     <li><span><a href="#4.2-Exogeneity-of-age-at-arrival" data-toc-modified-id="4.2-Exogeneity-of-age-at-arrival-4.2">4.2 Exogeneity of age at arrival</a></span></li>
#         <li><span><a href="#4.3-Cultural-connotations-in-language" data-toc-modified-id="4.3-Cultural-connotations-in-language-4.3">4.3 Cultural connotations in language</a></span></li></ul></li>
#
# <li><span><a href="#5.-Replication" data-toc-modified-id="#5.-Replication-5">5. Replication</a></span><ul class="toc-item"><li><span><a href="#5.1-Main-result" data-toc-modified-id="5.1-Main-result-5.1">5.1 Main result</a></span></li><li><span><a href="#5.2-Robustness-checks-in-the-benchmark" data-toc-modified-id="5.2-Robustness-checks-in-the-benchmark-5.2">5.2 Robustness checks in the benchmark</a></span></li></ul></li>
# <li><span><a href="#6.-Robustness-checks-and-extensions" data-toc-modified-id="#6.-Robustness-checks-and-extensions-6">6. Robustness checks and extensions</a></span><ul class="toc-item"><li><span><a href="#6.1-Durbin-Wu-Hausman-test" data-toc-modified-id="6.1-Durbin-Wu-Hausman-test-6.1">6.1 Durbin Wu Hausman test</a></span></li><li><span><a href="#6.2-Control-for-residence-location" data-toc-modified-id="6.2-Control-for=residence-location-6.2">6.2 Control for residence location</a></span></li><li><span><a href="#6.3-English-effect-on-outcome-gap-between-immigrants-and-spouses" data-toc-modified-id="6.3-English-effect-on-outcome-gap-between-immigrants-and-spouses-6.3">6.3 English effect on outcome gap between immigrants and spouses</a></span></li></ul></li>
# <li><span><a href="#7.-Conclusion" data-toc-modified-id="7.-Conclusion-7">7. Conclusion</a></span></li><li><span><a href="#8.-References" data-toc-modified-id="8.-References-8">8. References</a></span></li></ul></div>

# %% [markdown]
# ---
# # 1. Introduction
# ---
# Among numerous scholars, Beakley and Chin (2010) discuss the effect of English proficiency on social assimilation between immigrants in the US. While it is intuitive that immigrants with better English skills would be melt in the US society more thoroughly, competitive theories can be offered to explain the correlation between the two properties. A theory is that English skill lowers the difficulty, or, as economists put it, the cost of across group social interactions. As a result, interaction with the local increases when the immigrants have better English skills. On the other hand, it can also be argued that it is the people, who prefer the destination country’s culture and society more, self-selected into immigrating into the US. And the higher English level of this group of people is another product of their endorsement towards the US culture. So the correlation is just driven by the cultural preference as a confounding factor, rather than causation.
#
# Beakley and Chin (2010) show evidential support for the theory that English proficiency causes social integrations using 2000 census data. The empirical strategy employed is to use the age of arrival as an instrumental variable. The justification of this practice is that the age of arrival correlates with the ability to acquire a second language and at the same time, does not affect other endogenous variables. They also exploite immigrants from Anglophone countries as a control group for non-linguistic effects of age at arrival. The IV esitmation confirms the causal effect of English proficiency on social outcome. English proficiency raises the probabilities of being divorced, having a more educated, higher earning, or US-born spouse, having fewer children.
#
# In this notebook, we will replicate this study of Beakley and Chin. After that, a discussion of the conceptual framework and robustness checks will be offered. Our analysis explores some conceptual and econometrics issues in the original study.
#
# This notebook is structured as follows. In the next section, we present the theoretical background that raises the authors' research interest. Following that we will give a brief data description. In Section 3, we analyze the instrumental variable strategy employed and the specification of the estimations. The main highlights of this notebook are sections 4 to 7. In Section 4, we will discuss some problems of the conceptual framework of the authors. Section 5 presents our replication of the results in the benchmark. Section 6 consists of various robustness checks adn extensions based on the benchmark. in Section 7 we sum up this paper.

# %% [markdown]
# ---
# # 2. Theoretical Background and Data Description
# ---
# ## 2.1 Theoretical Background
#
# Researchers are motivated to study the factors contributing to the social assimilation of immigrants. Previous studies, such as Gillian Stevens and Gray Swicegood (1987), Brian Duncan and Stephen J. Trejo (2007), Xin Meng and Robert G. Gregory (2005) have shown that English proficiency raises the probability of intermarriage. Duncan and Trejo (2007) particularly examine Mexican immigrants’ marital outcomes. They investigate certain characteristics of Mexican Americans. It is revealed that Mexican Americans who are married to non-Mexicans “tend to speak better English, be more educated, be more likely to work, and earn more compared to Mexican Americans married to either Mexican immigrants or US-born Mexicans”. Similar evidence to support English proficiency relationships with fertility outcomes are given by Ann Marie Sorenson et al. (1988), and Swicegood et al. (1988). Apart from marital and fertility outcomes, English proficiency also correlated with residential location outcomes, as Edward Funkhouser and Fernando A. Ramos (1993) and Maude Toussaint-Comeau and Sherrie L. W. Rhine (2004) demonstrated. The relationship between the proficiency of the dominant language in the destination country and the level of social assimilation brings significant policy implications. If knowing the mainstream language helps immigrants integrating into their new home, then policies help improving language skills can certainly enhance social harmony.
#
# But the nature of that correlation is still debatable. The “casual hypothesis” claims that language proficiency lower the effort, or in an economics terminology - the “cost” of social interaction with the local residents. Under this partial equilibrium framework, lowering the cost of social interaction implies an increase in the consumption of it. Therefore the language proficiency causes social interaction. However, this hypothesis comes across challenges. The first one is that language proficiency is correlated with other variables that will affect the social outcome. For example, how well a person masters a second language is correlated with his ability such as IQ. It is possible that an immigrant is getting a well-paid simply because of his higher ability instead of language proficiency. Secondly, even if there is a direct relationship between language proficiency and social outcome, it still remains doubtful if it is the people have assimilated into the destination country, such as by having a spouse or a job in the destination country, can improve the English proficiency during their stay in the destination country.

# %% [markdown]
# ## 2.2 Data Description
#
# Our data is obtained from the 2000 US Census of Population and Housing. Measures including English level, a crucial variable for our computation of the instrumental variable, are self-reported by the respondent as a categorical variable. The census was conducted on household level. We can identify each respondent’s and the cohabiting spouse’s answer. Martial outcomes in social assimilation are therefore possible to be shown.
#
# We subset the data to childhood immigrants currently aged from 25 to 55. A childhood immigrant is an immigrant who was under age 15 upon arrival in the US. A childhood immigrant typically did not choose to immigrate but just follow the parents’ decision. Under our definition, a childhood immigrant spent at least 11 years and at most 55 years in the US. The minimum and maximum age of observations ensure enough years are given to expose to the English environment, at the same time avoid selection biases due to retired and deceased immigrants.
#
# We further subset the data by their origins’ English tie. A childhood immigrant who has a non-English-speaking country of birth belongs to the treatment group. A childhood immigrant whose countries of birth have English as 1) an official language and 2) predominant language, belongs to the control group
#
# Our descriptive statistics can be shown as follows.

# %%
sumlist_ind = ["eng", "age", "female", "white" , "black" , "asianpi"  , "other",  "multi" , "hispdum" ,"yrssch", "marriedpresent" ,"divorced" ,"evermarried", "nchild", "haskid" ,"singleparent" ,"nevermarried_haskid", "share_bpld_minusself" ,"abovemean_bpld2" ,"ancestpct_minusself" ,"abovemean_ancestry2" ,"nengdom", "young9","perwt2" ]
sumlist_mat = ["spouseeng", "marriednative" ,"couplesamebpld", "couplesameancestry1", "spouseage", "spouseyrssch" ,"yrssch" ,"spouselnwage", "spouseworkedly" ,"bothworked" ,"nchild" ,"haskid", "nengdom", "young9","perwt2"]

#droppingh Null entry in english skills
df_ind['eng'].replace('  ', np.nan, inplace=True)
df_ind= df_ind.dropna(subset=['eng'])

df_ind["young9"] = np.where(df_ind.agearr<=9,1,0)

dfs_ind= df_ind[sumlist_ind]

dfs_ind.loc[(dfs_ind["nengdom"] ==1 ), 'English group'] = 'Treatment Group : Born in non-English-speaking country'
dfs_ind.loc[(dfs_ind["nengdom"] ==1 )&( dfs_ind["young9"] == 1), 'Age group'] = 'Arrived Age 0-9'
dfs_ind.loc[(dfs_ind["nengdom"] ==1 )&( dfs_ind["young9"] == 0), 'Age group'] = 'Arrived Age 10-14'

dfs_ind.loc[(dfs_ind["nengdom"] ==0 ), 'English group'] = 'Control Group: Born in English-speaking country'
dfs_ind.loc[(dfs_ind["nengdom"] ==0 )&( dfs_ind["young9"] == 1), 'Age group'] = 'Arrived Age 0-9'
dfs_ind.loc[(dfs_ind["nengdom"] ==0 )&( dfs_ind["young9"] == 0), 'Age group'] = 'Arrived Age 10-14'

dfs_ind= dfs_ind.drop(['nengdom', 'young9'], axis=1)

#droppingh Null entry in english skills
df_mat['eng'].replace('  ', np.nan, inplace=True)
df_mat= df_mat.dropna(subset=['eng'])

df_mat["young9"] = df_mat["agearr"] <=9

# keeping useful variables

dfs_mat= df_mat[sumlist_mat]

dfs_mat.loc[(dfs_mat["nengdom"] ==1 ), 'English group'] = 'Treatment Group : Born in non-English-speaking country'
dfs_mat.loc[(dfs_mat["nengdom"] ==1 )&( dfs_mat["young9"] == 1), 'Age group'] = 'Arrived Age 0-9'
dfs_mat.loc[(dfs_mat["nengdom"] ==1 )&( dfs_mat["young9"] == 0), 'Age group'] = 'Arrived Age 10-14'

dfs_mat.loc[(dfs_mat["nengdom"] ==0 ), 'English group'] = 'Control Group: Born in English-speaking country'
dfs_mat.loc[(dfs_mat["nengdom"] ==0 )&( dfs_mat["young9"] == 1), 'Age group'] = 'Arrived Age 0-9'
dfs_mat.loc[(dfs_mat["nengdom"] ==0 )&( dfs_mat["young9"] == 0), 'Age group'] = 'Arrived Age 10-14'
dfs_mat = dfs_mat.rename(columns={'nchild': 'nchild_spouse', 'haskid': 'haskid_spouse'})
dfs_mat= dfs_mat.drop(['nengdom', 'young9'], axis=1)

# the observations is to be weighted by perwt2
sumlist_ind.remove("nengdom")
sumlist_ind.remove("young9")
sumlist_ind.remove("perwt2")
sumlist_mat.remove("nengdom")
sumlist_mat.remove("young9")
sumlist_mat.remove("perwt2")


dfs_ind= dfs_ind.drop(['perwt2'], axis=1)
dfs_mat= dfs_mat.drop(['perwt2'], axis=1)
list_table1 = list(dfs_ind.columns)
list_table1.remove("English group")
list_table1.remove("Age group")
list_table2 = list(dfs_mat.columns)
list_table2.remove("English group")
list_table2.remove("Age group")


for i in list_table1:
    dfs_ind = dfs_ind.rename(columns={i: Dict_for_sumlist1[i]})
for i in list_table2:
    dfs_mat = dfs_mat.rename(columns={i: Dict_for_sumlist1[i]})
# Out:
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
print("Table 1a: the mean and SD of variables for the control group and treatment group")
print("This table refers to column (4) and (1) in Table 1 of the benchmark" )


print("The mean of variables for control group and treatment group")
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(dfs_ind.groupby(["English group"]).mean(), dfs_mat.groupby(["English group"]).mean())

print("The standard deviation of variables for control group and treatment group")
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(dfs_ind.groupby(["English group"]).std(), dfs_mat.groupby(["English group"]).mean())
# Out:
# Table 1a: the mean and SD of variables for the control group and treatment group
# This table refers to column (4) and (1) in Table 1 of the benchmark
# The mean of variables for control group and treatment group
#                                                     English-speaking ability ordinal measure  \
# English group
# Control Group: Born in English-speaking country                                     2.980587
# Treatment Group : Born in non-English-speaking ...                                  2.714701
#
#                                                           Age    Female  \
# English group
# Control Group: Born in English-speaking country     38.763566  0.529178
# Treatment Group : Born in non-English-speaking ...  36.616986  0.501723
#
#                                                        White     Black  \
# English group
# Control Group: Born in English-speaking country     0.690274  0.225087
# Treatment Group : Born in non-English-speaking ...  0.553140  0.028159
#
#                                                     Asian/Pacific Islander  \
# English group
# Control Group: Born in English-speaking country                   0.027673
# Treatment Group : Born in non-English-speaking ...                0.118414
#
#                                                     Other single race  \
# English group
# Control Group: Born in English-speaking country              0.018989
# Treatment Group : Born in non-English-speaking ...           0.247922
#
#                                                     Multiracial  Hispanic  \
# English group
# Control Group: Born in English-speaking country        0.037978  0.012157
# Treatment Group : Born in non-English-speaking ...     0.052365  0.521571
#
#                                                     Years of schooling  \
# English group
# Control Group: Born in English-speaking country              14.474017
# Treatment Group : Born in non-English-speaking ...           13.089313
#
#                                                     Is currently married with spouse present  \
# English group
# Control Group: Born in English-speaking country                                     0.571562
# Treatment Group : Born in non-English-speaking ...                                  0.605827
#
#                                                     Is currently divorced  \
# English group
# Control Group: Born in English-speaking country                  0.122183
# Treatment Group : Born in non-English-speaking ...               0.097178
#
#                                                     Has ever married  \
# English group
# Control Group: Born in English-speaking country             0.748834
# Treatment Group : Born in non-English-speaking ...          0.771019
#
#                                                     Number of children living in same household  \
# English group
# Control Group: Born in English-speaking country                                        0.972250
# Treatment Group : Born in non-English-speaking ...                                     1.244415
#
#                                                     Has a child living in same household  \
# English group
# Control Group: Born in English-speaking country                                 0.509649
# Treatment Group : Born in non-English-speaking ...                              0.584227
#
#                                                     Is a single parent  \
# English group
# Control Group: Born in English-speaking country               0.105012
# Treatment Group : Born in non-English-speaking ...            0.102999
#
#                                                     Is a never married, single parent  \
# English group
# Control Group: Born in English-speaking country                              0.034693
# Treatment Group : Born in non-English-speaking ...                           0.029651
#
#                                                     Fraction of PUMA population from same country of birth  \
# English group
# Control Group: Born in English-speaking country                                              0.007964
# Treatment Group : Born in non-English-speaking ...                                           0.064826
#
#                                                     Fraction from same country of birth is above national mean for the country of birth  \
# English group
# Control Group: Born in English-speaking country                                              0.356678
# Treatment Group : Born in non-English-speaking ...                                           0.343112
#
#                                                     Fraction of PUMA population with same primary ancestry  \
# English group
# Control Group: Born in English-speaking country                                              0.044566
# Treatment Group : Born in non-English-speaking ...                                           0.117402
#
#                                                     Fraction with same ancestry is above national mean for the primary ancestry
# English group
# Control Group: Born in English-speaking country                                              0.368470
# Treatment Group : Born in non-English-speaking ...                                           0.369346
#                                                     Spouse English-speaking ability ordinal measure  \
# English group
# Control Group: Born in English-speaking country                                            2.978607
# Treatment Group : Born in non-English-speaking ...                                         2.587381
#
#                                                     Spouse is US-born  \
# English group
# Control Group: Born in English-speaking country              0.812874
# Treatment Group : Born in non-English-speaking ...           0.499035
#
#                                                     Spouse has the same country of birth  \
# English group
# Control Group: Born in English-speaking country                                 0.089315
# Treatment Group : Born in non-English-speaking ...                              0.390376
#
#                                                     Spouse has the same ancestry  \
# English group
# Control Group: Born in English-speaking country                         0.243836
# Treatment Group : Born in non-English-speaking ...                      0.543241
#
#                                                     Spouse age  \
# English group
# Control Group: Born in English-speaking country      40.771411
# Treatment Group : Born in non-English-speaking ...   38.176907
#
#                                                     Spouse years of schooling  \
# English group
# Control Group: Born in English-speaking country                     14.528200
# Treatment Group : Born in non-English-speaking ...                  12.965574
#
#                                                     Years of schooling  \
# English group
# Control Group: Born in English-speaking country              14.597188
# Treatment Group : Born in non-English-speaking ...           13.103995
#
#                                                     Spouse log(wages last year)  \
# English group
# Control Group: Born in English-speaking country                       10.362746
# Treatment Group : Born in non-English-speaking ...                    10.191646
#
#                                                     Spouse worked last year  \
# English group
# Control Group: Born in English-speaking country                    0.881479
# Treatment Group : Born in non-English-speaking ...                 0.825765
#
#                                                     Both worked last year  \
# English group
# Control Group: Born in English-speaking country                  0.779933
# Treatment Group : Born in non-English-speaking ...               0.701292
#
#                                                     Number of children living in same household, only individuals married spouse present  \
# English group
# Control Group: Born in English-speaking country                                              1.397906
# Treatment Group : Born in non-English-speaking ...                                           1.736242
#
#                                                     Has a child living in same household, only individuals married with spouse present
# English group
# Control Group: Born in English-speaking country                                              0.710372
# Treatment Group : Born in non-English-speaking ...                                           0.797043
# The standard deviation of variables for control group and treatment group
#                                                     English-speaking ability ordinal measure  \
# English group
# Control Group: Born in English-speaking country                                     0.166150
# Treatment Group : Born in non-English-speaking ...                                  0.624551
#
#                                                          Age    Female  \
# English group
# Control Group: Born in English-speaking country     8.440097  0.499158
# Treatment Group : Born in non-English-speaking ...  8.295871  0.499999
#
#                                                        White     Black  \
# English group
# Control Group: Born in English-speaking country     0.462389  0.417648
# Treatment Group : Born in non-English-speaking ...  0.497170  0.165428
#
#                                                     Asian/Pacific Islander  \
# English group
# Control Group: Born in English-speaking country                   0.164036
# Treatment Group : Born in non-English-speaking ...                0.323098
#
#                                                     Other single race  \
# English group
# Control Group: Born in English-speaking country              0.136488
# Treatment Group : Born in non-English-speaking ...           0.431808
#
#                                                     Multiracial  Hispanic  \
# English group
# Control Group: Born in English-speaking country        0.191146  0.109591
# Treatment Group : Born in non-English-speaking ...     0.222762  0.499536
#
#                                                     Years of schooling  \
# English group
# Control Group: Born in English-speaking country               2.469523
# Treatment Group : Born in non-English-speaking ...            3.476692
#
#                                                     Is currently married with spouse present  \
# English group
# Control Group: Born in English-speaking country                                     0.494862
# Treatment Group : Born in non-English-speaking ...                                  0.488674
#
#                                                     Is currently divorced  \
# English group
# Control Group: Born in English-speaking country                  0.327504
# Treatment Group : Born in non-English-speaking ...               0.296201
#
#                                                     Has ever married  \
# English group
# Control Group: Born in English-speaking country             0.433692
# Treatment Group : Born in non-English-speaking ...          0.420178
#
#                                                     Number of children living in same household  \
# English group
# Control Group: Born in English-speaking country                                        1.171388
# Treatment Group : Born in non-English-speaking ...                                     1.335926
#
#                                                     Has a child living in same household  \
# English group
# Control Group: Born in English-speaking country                                 0.499917
# Treatment Group : Born in non-English-speaking ...                              0.492856
#
#                                                     Is a single parent  \
# English group
# Control Group: Born in English-speaking country               0.306574
# Treatment Group : Born in non-English-speaking ...            0.303958
#
#                                                     Is a never married, single parent  \
# English group
# Control Group: Born in English-speaking country                              0.183005
# Treatment Group : Born in non-English-speaking ...                           0.169623
#
#                                                     Fraction of PUMA population from same country of birth  \
# English group
# Control Group: Born in English-speaking country                                              0.018780
# Treatment Group : Born in non-English-speaking ...                                           0.105865
#
#                                                     Fraction from same country of birth is above national mean for the country of birth  \
# English group
# Control Group: Born in English-speaking country                                               0.47903
# Treatment Group : Born in non-English-speaking ...                                            0.47475
#
#                                                     Fraction of PUMA population with same primary ancestry  \
# English group
# Control Group: Born in English-speaking country                                              0.061740
# Treatment Group : Born in non-English-speaking ...                                           0.156028
#
#                                                     Fraction with same ancestry is above national mean for the primary ancestry
# English group
# Control Group: Born in English-speaking country                                              0.482402
# Treatment Group : Born in non-English-speaking ...                                           0.482630
#                                                     Spouse English-speaking ability ordinal measure  \
# English group
# Control Group: Born in English-speaking country                                            2.978607
# Treatment Group : Born in non-English-speaking ...                                         2.587381
#
#                                                     Spouse is US-born  \
# English group
# Control Group: Born in English-speaking country              0.812874
# Treatment Group : Born in non-English-speaking ...           0.499035
#
#                                                     Spouse has the same country of birth  \
# English group
# Control Group: Born in English-speaking country                                 0.089315
# Treatment Group : Born in non-English-speaking ...                              0.390376
#
#                                                     Spouse has the same ancestry  \
# English group
# Control Group: Born in English-speaking country                         0.243836
# Treatment Group : Born in non-English-speaking ...                      0.543241
#
#                                                     Spouse age  \
# English group
# Control Group: Born in English-speaking country      40.771411
# Treatment Group : Born in non-English-speaking ...   38.176907
#
#                                                     Spouse years of schooling  \
# English group
# Control Group: Born in English-speaking country                     14.528200
# Treatment Group : Born in non-English-speaking ...                  12.965574
#
#                                                     Years of schooling  \
# English group
# Control Group: Born in English-speaking country              14.597188
# Treatment Group : Born in non-English-speaking ...           13.103995
#
#                                                     Spouse log(wages last year)  \
# English group
# Control Group: Born in English-speaking country                       10.362746
# Treatment Group : Born in non-English-speaking ...                    10.191646
#
#                                                     Spouse worked last year  \
# English group
# Control Group: Born in English-speaking country                    0.881479
# Treatment Group : Born in non-English-speaking ...                 0.825765
#
#                                                     Both worked last year  \
# English group
# Control Group: Born in English-speaking country                  0.779933
# Treatment Group : Born in non-English-speaking ...               0.701292
#
#                                                     Number of children living in same household, only individuals married spouse present  \
# English group
# Control Group: Born in English-speaking country                                              1.397906
# Treatment Group : Born in non-English-speaking ...                                           1.736242
#
#                                                     Has a child living in same household, only individuals married with spouse present
# English group
# Control Group: Born in English-speaking country                                              0.710372
# Treatment Group : Born in non-English-speaking ...                                           0.797043

# %%
print("Table 1b: the mean and SD of variables for the age groups")
print("This table refers to column (5), (6), (2) and (3) in Table 1 of the benchmark" )


print("The mean of variables for age groups")
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(dfs_ind.groupby(["English group","Age group"]).mean(), dfs_mat.groupby(["English group","Age group"]).mean())

print("The standard deviation of variables for age groups")
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(dfs_ind.groupby(["English group","Age group"]).std(), dfs_mat.groupby(["English group","Age group"]).std())
# Out:
# Table 1b: the mean and SD of variables for the age groups
# This table refers to column (5), (6), (2) and (3) in Table 1 of the benchmark
# The mean of variables for age groups
#                                                                       English-speaking ability ordinal measure  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                    2.981686
#                                                    Arrived Age 10-14                                  2.977429
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                    2.871498
#                                                    Arrived Age 10-14                                  2.429342
#
#                                                                             Age  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    39.253070
#                                                    Arrived Age 10-14  37.357250
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    36.915149
#                                                    Arrived Age 10-14  36.074351
#
#                                                                         Female  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.517638
#                                                    Arrived Age 10-14  0.562332
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.514670
#                                                    Arrived Age 10-14  0.478161
#
#                                                                          White  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.784599
#                                                    Arrived Age 10-14  0.419283
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.610062
#                                                    Arrived Age 10-14  0.449547
#
#                                                                          Black  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.146098
#                                                    Arrived Age 10-14  0.452018
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.028415
#                                                    Arrived Age 10-14  0.027695
#
#                                                                       Asian/Pacific Islander  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                  0.023933
#                                                    Arrived Age 10-14                0.038416
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                  0.101546
#                                                    Arrived Age 10-14                0.149111
#
#                                                                       Other single race  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9             0.015765
#                                                    Arrived Age 10-14           0.028251
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9             0.207741
#                                                    Arrived Age 10-14           0.321049
#
#                                                                       Multiracial  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9       0.029605
#                                                    Arrived Age 10-14     0.062033
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9       0.052237
#                                                    Arrived Age 10-14     0.052598
#
#                                                                       Hispanic  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.012383
#                                                    Arrived Age 10-14  0.011510
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.450864
#                                                    Arrived Age 10-14  0.650252
#
#                                                                       Years of schooling  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9             14.530509
#                                                    Arrived Age 10-14           14.310811
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9             13.710728
#                                                    Arrived Age 10-14           11.943063
#
#                                                                       Is currently married with spouse present  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                    0.592591
#                                                    Arrived Age 10-14                                  0.510937
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                    0.591752
#                                                    Arrived Age 10-14                                  0.631535
#
#                                                                       Is currently divorced  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                 0.125373
#                                                    Arrived Age 10-14               0.112988
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                 0.108141
#                                                    Arrived Age 10-14               0.077152
#
#                                                                       Has ever married  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9            0.767568
#                                                    Arrived Age 10-14          0.694826
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9            0.761897
#                                                    Arrived Age 10-14          0.787681
#
#                                                                       Number of children living in same household  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                       0.968783
#                                                    Arrived Age 10-14                                     0.982212
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                       1.144813
#                                                    Arrived Age 10-14                                     1.425683
#
#                                                                       Has a child living in same household  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                0.506243
#                                                    Arrived Age 10-14                              0.519432
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                0.559275
#                                                    Arrived Age 10-14                              0.629638
#
#                                                                       Is a single parent  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9              0.093349
#                                                    Arrived Age 10-14            0.138633
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9              0.103195
#                                                    Arrived Age 10-14            0.102640
#
#                                                                       Is a never married, single parent  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                             0.026529
#                                                    Arrived Age 10-14                           0.058229
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                             0.027926
#                                                    Arrived Age 10-14                           0.032802
#
#                                                                       Fraction of PUMA population from same country of birth  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.006077
#                                                    Arrived Age 10-14                                           0.013380
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.053551
#                                                    Arrived Age 10-14                                           0.085421
#
#                                                                       Fraction from same country of birth is above national mean for the country of birth  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.354117
#                                                    Arrived Age 10-14                                           0.364026
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.318821
#                                                    Arrived Age 10-14                                           0.387485
#
#                                                                       Fraction of PUMA population with same primary ancestry  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.047387
#                                                    Arrived Age 10-14                                           0.036520
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.108715
#                                                    Arrived Age 10-14                                           0.133040
#
#                                                                       Fraction with same ancestry is above national mean for the primary ancestry
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.371457
#                                                    Arrived Age 10-14                                           0.359955
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.357619
#                                                    Arrived Age 10-14                                           0.390458
#                                                                       Spouse English-speaking ability ordinal measure  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                           2.980906
#                                                    Arrived Age 10-14                                         2.970929
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                           2.758109
#                                                    Arrived Age 10-14                                         2.293690
#
#                                                                       Spouse is US-born  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9             0.865519
#                                                    Arrived Age 10-14           0.636847
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9             0.636782
#                                                    Arrived Age 10-14           0.263271
#
#                                                                       Spouse has the same country of birth  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                0.052804
#                                                    Arrived Age 10-14                              0.211397
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                0.263390
#                                                    Arrived Age 10-14                              0.607723
#
#                                                                       Spouse has the same ancestry  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                        0.218093
#                                                    Arrived Age 10-14                      0.326992
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                        0.458948
#                                                    Arrived Age 10-14                      0.682739
#
#                                                                       Spouse age  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9     41.111965
#                                                    Arrived Age 10-14   39.632713
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9     38.582139
#                                                    Arrived Age 10-14   37.483322
#
#                                                                       Spouse years of schooling  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                    14.588204
#                                                    Arrived Age 10-14                  14.325539
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                    13.599222
#                                                    Arrived Age 10-14                  11.861887
#
#                                                                       Years of schooling  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9             14.627805
#                                                    Arrived Age 10-14           14.494630
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9             13.820854
#                                                    Arrived Age 10-14           11.859057
#
#                                                                       Spouse log(wages last year)  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                      10.362293
#                                                    Arrived Age 10-14                    10.364303
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                      10.257401
#                                                    Arrived Age 10-14                    10.065613
#
#                                                                       Spouse worked last year  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                   0.882938
#                                                    Arrived Age 10-14                 0.876543
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                   0.848429
#                                                    Arrived Age 10-14                 0.786248
#
#                                                                       Both worked last year  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                 0.782613
#                                                    Arrived Age 10-14               0.770866
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                 0.733346
#                                                    Arrived Age 10-14               0.644896
#
#                                                                       Number of children living in same household, only individuals married spouse present  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             1.378366
#                                                    Arrived Age 10-14                                           1.463242
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             1.618122
#                                                    Arrived Age 10-14                                           1.938413
#
#                                                                       Has a child living in same household, only individuals married with spouse present
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.698985
#                                                    Arrived Age 10-14                                           0.748450
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.772752
#                                                    Arrived Age 10-14                                           0.838620
# The standard deviation of variables for age groups
#                                                                       English-speaking ability ordinal measure  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                    0.162508
#                                                    Arrived Age 10-14                                  0.176167
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                    0.421750
#                                                    Arrived Age 10-14                                  0.806270
#
#                                                                            Age  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    8.435833
#                                                    Arrived Age 10-14  8.293738
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    8.391007
#                                                    Arrived Age 10-14  8.091798
#
#                                                                         Female  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.499702
#                                                    Arrived Age 10-14  0.496137
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.499787
#                                                    Arrived Age 10-14  0.499527
#
#                                                                          White  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.411111
#                                                    Arrived Age 10-14  0.493479
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.487738
#                                                    Arrived Age 10-14  0.497452
#
#                                                                          Black  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.353213
#                                                    Arrived Age 10-14  0.497730
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.166155
#                                                    Arrived Age 10-14  0.164098
#
#                                                                       Asian/Pacific Islander  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                  0.152846
#                                                    Arrived Age 10-14                0.192212
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                  0.302052
#                                                    Arrived Age 10-14                0.356201
#
#                                                                       Other single race  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9             0.124568
#                                                    Arrived Age 10-14           0.165702
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9             0.405692
#                                                    Arrived Age 10-14           0.466884
#
#                                                                       Multiracial  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9       0.169498
#                                                    Arrived Age 10-14     0.241233
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9       0.222505
#                                                    Arrived Age 10-14     0.223231
#
#                                                                       Hispanic  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9    0.110590
#                                                    Arrived Age 10-14  0.106672
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9    0.497582
#                                                    Arrived Age 10-14  0.476894
#
#                                                                       Years of schooling  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9              2.458518
#                                                    Arrived Age 10-14            2.494056
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9              2.958999
#                                                    Arrived Age 10-14            4.025796
#
#                                                                       Is currently married with spouse present  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                    0.491365
#                                                    Arrived Age 10-14                                  0.499918
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                    0.491512
#                                                    Arrived Age 10-14                                  0.482392
#
#                                                                       Is currently divorced  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                 0.331150
#                                                    Arrived Age 10-14               0.316602
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                 0.310560
#                                                    Arrived Age 10-14               0.266835
#
#                                                                       Has ever married  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9            0.422394
#                                                    Arrived Age 10-14          0.460516
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9            0.425924
#                                                    Arrived Age 10-14          0.408953
#
#                                                                       Number of children living in same household  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                       1.170186
#                                                    Arrived Age 10-14                                     1.174865
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                       1.272928
#                                                    Arrived Age 10-14                                     1.425808
#
#                                                                       Has a child living in same household  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                0.499974
#                                                    Arrived Age 10-14                              0.499660
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                0.496476
#                                                    Arrived Age 10-14                              0.482906
#
#                                                                       Is a single parent  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9              0.290929
#                                                    Arrived Age 10-14            0.345590
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9              0.304215
#                                                    Arrived Age 10-14            0.303491
#
#                                                                       Is a never married, single parent  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                             0.160707
#                                                    Arrived Age 10-14                           0.234194
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                             0.164761
#                                                    Arrived Age 10-14                           0.178120
#
#                                                                       Fraction of PUMA population from same country of birth  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.014350
#                                                    Arrived Age 10-14                                           0.027100
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.098546
#                                                    Arrived Age 10-14                                           0.115257
#
#                                                                       Fraction from same country of birth is above national mean for the country of birth  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.478260
#                                                    Arrived Age 10-14                                           0.481199
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.466022
#                                                    Arrived Age 10-14                                           0.487181
#
#                                                                       Fraction of PUMA population with same primary ancestry  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.062808
#                                                    Arrived Age 10-14                                           0.057842
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.147841
#                                                    Arrived Age 10-14                                           0.168651
#
#                                                                       Fraction with same ancestry is above national mean for the primary ancestry
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.483210
#                                                    Arrived Age 10-14                                           0.480032
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.479302
#                                                    Arrived Age 10-14                                           0.487858
#                                                                       Spouse English-speaking ability ordinal measure  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                           0.162387
#                                                    Arrived Age 10-14                                         0.197274
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                           0.599838
#                                                    Arrived Age 10-14                                         0.923215
#
#                                                                       Spouse is US-born  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9             0.341184
#                                                    Arrived Age 10-14           0.480979
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9             0.480931
#                                                    Arrived Age 10-14           0.440414
#
#                                                                       Spouse has the same country of birth  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                0.223651
#                                                    Arrived Age 10-14                              0.408359
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                0.440476
#                                                    Arrived Age 10-14                              0.488265
#
#                                                                       Spouse has the same ancestry  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                        0.412972
#                                                    Arrived Age 10-14                      0.469191
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                        0.498316
#                                                    Arrived Age 10-14                      0.465417
#
#                                                                       Spouse age  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9      8.879019
#                                                    Arrived Age 10-14    9.004840
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9      9.119282
#                                                    Arrived Age 10-14    9.096449
#
#                                                                       Spouse years of schooling  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                     2.547842
#                                                    Arrived Age 10-14                   2.576121
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                     3.284479
#                                                    Arrived Age 10-14                   4.176946
#
#                                                                       Years of schooling  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9              2.420732
#                                                    Arrived Age 10-14            2.462243
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9              2.904518
#                                                    Arrived Age 10-14            4.035474
#
#                                                                       Spouse log(wages last year)  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                       1.048971
#                                                    Arrived Age 10-14                     0.960799
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                       0.991118
#                                                    Arrived Age 10-14                     0.986808
#
#                                                                       Spouse worked last year  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                   0.321509
#                                                    Arrived Age 10-14                 0.329012
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                   0.358608
#                                                    Arrived Age 10-14                 0.409960
#
#                                                                       Both worked last year  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                 0.412487
#                                                    Arrived Age 10-14               0.420341
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                 0.442214
#                                                    Arrived Age 10-14               0.478552
#
#                                                                       Number of children living in same household, only individuals married spouse present  \
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             1.204742
#                                                    Arrived Age 10-14                                           1.191644
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             1.255057
#                                                    Arrived Age 10-14                                           1.353711
#
#                                                                       Has a child living in same household, only individuals married with spouse present
# English group                                      Age group
# Control Group: Born in English-speaking country    Arrived Age 0-9                                             0.458720
#                                                    Arrived Age 10-14                                           0.433968
# Treatment Group : Born in non-English-speaking ... Arrived Age 0-9                                             0.419058
#                                                    Arrived Age 10-14                                           0.367886

# %% [markdown]
# Our descriptive statistics, althought slightly deviate from the benchmarks,give support to the age-language relationship picture we drawn. Late arrivers in treatment group and control group demonstrate a significant difference in English level, while earlier arrivers’ English level are similar.

# %% [markdown]
# ---
# # 3. Identification and Empirical Strategy
# ---
#
# The challenges require advanced econometrics techniques beyond ordinary least square estimation. The authors choose to use the method of instrumental variable to tackle the issues. What stands out the benchmark compared to other literature is that the authors sensibly make use of the fact that children acquire foreign languages with ease. This strategy is supported by research in physiological studies where researchers identified the physiological feature in the brain which is known as the “critical period of language acquisition” (Eric H. Lenneberg 1967).
#
# The social outcomes are assumed to be a function of age at arrival for non-Anglophone-origin immigrants. If a person coming from a non-English speaking country immigrates to the US at a younger age, one’s English level is going to be closer to the native speakers. It is further assumed that there is no direct effect of age of arrival on the social assimilation. Therefore age-of-arrival will be suitable IV to control for the ability effect.

# %% [markdown]
# Our instrumental variable is define as follows:
#
# \begin{equation}\tag{1}
#   k_{ija}= max (0, a-9) * I (j\quad  is\quad  a\quad  non-English-speaking\quad  country)
# \end{equation}
#
# where *a* is age at arrival, *I*(·) is the indicator function, and *j* is country of birth
#
#
#
# \begin{equation}\tag{2}
# ENG_{ija}= \alpha_{1}+\pi_{1}k_{ija}+\delta_{1a}+\gamma_{1j}+W_{ija}'\rho_{1}+\epsilon_{1ija}
# \end{equation}
#
# for individual *i*  born in country *j* arriving in the US at age *a*.  $ENG_{ija}$ is a measure of English language skills, $δ_{1a}$ is a set of age-at-arrival dummies, $γ_{1j}$  is a set of country-of-birth dummies, and $w_{ija}$  is a vector of exogenous explanatory variables (e.g., age, sex, race).
#
#
#
# The OLS esitmation is given by
# \begin{equation}\tag{3}
# y_{ija}= \alpha_{1}+ \beta ENG_{ija} + \delta_{a}+\gamma_{j} + W_{ija}'\rho + \epsilon_{ija}
# \end{equation}
#
# for individual *i*  born in country *j* arriving in the US at age *a*. $y_{ija}$ is the outcome , $ENG_{ija}$ is a measure of English language skills (the endogenous regressor), $δ_{a}$ is a set of age-at-arrival dummies, $γ_{j}$  is a set of country-of-birth dummies, and $w_{ija}$  is a vector of exogenous explanatory variables (e.g., age, sex, race).
#
#
# The OLS estimation of equation (3) will be biased because of endogeneity issue. The IV strategy we employed is to get
# the first stage esitmate of $\hat{ENG_{ija}}$ using equation (2). And then use $\hat{ENG_{ija}}$ instead of  $ENG_{ija}$ in the second stage estimate, i.e. equation (4)
#
# \begin{equation}\tag{4}
# y_{ija}= \alpha_{1}+ \beta^{2SLS} \hat{ENG_{ija}} + \delta_{a}+\gamma_{j} + W_{ija}'\rho + \epsilon_{ija}
# \end{equation}
#
# The estimation of ${β^{2SLS}}$ will be our target.
#
# Our model can be visualized by a causal graph.
#
# Figure 1. Causal graph
# <img src="Graph/CausalGraph.jpg" width="700">

# %% [markdown]
# ---
# # 4. Conceptual issues in the benchmark
# ---
#
# ### 4.1 Social outcome and social assimilation
# It seems to us that the authors are treating *social outcome* and *social assimilation* as a pair of synonymies when they are analyzing the statistics result.
#
# It is not clear whether the variables measure the *wellness of the integration*. For example, why an immigrant having a child in the destination country implies that he or she better fitted into US society? Or why an immigrant and his or her spouse are both implies a higher level of social assimilation? We do not see any clear and strong intuition indicating the linkage between the proposed measures and our target concepts. Certainly, for some measures, a significantly low level indicates a potential integration problem. But we cannot tell if there is no problem by an increase in the level.
#
# A thought experiment can elaborate our point. Suppose there is a group of immigrant K from a specific country. If the mean wage of K-people (when fixing other variables) is very low, then it might indicate that they on margins in the labor market. But what if the mean-wage of K-people is very high? It would also mean that they process some systematic properties that the locals do not. These properties also differentiate K-people systematically from the locals. The high mean wage does not make them more integrated into the destination society, although they are absolutely better off in terms of living standards.
#
# An initial guess to solve the problem is to compare the difference of the mean of these variables between the immigrants and the US. If the deviation is small, then it means an immigrant is on average not having a higher or lower outcome from the locals.
#
# However, this is not a solution neither. This issue is more complicated by the US liberal tradition. In principle, individuals are free to choose their own form of life.  What does it mean if the immigrants are losing their “homeland features”? If k-people, after observing the undesirable outcome of keeping their “homeland features”, decide to abandon those. And they finally have an outcome having no difference in those outcomes than the locals. Are they really integrating in the US society in terms of the outcome? Or they are just integrating into the US on the surface, but they are not embracing the liberal spirit of the US, which more fundamental than those measure outcomes? To settle this debate, we have to go deep into a philosophical discussion of politics and culture. But that will not be our focus in this short article. We will just be cautious about the conceptual insufficiency of the result about certain outcomes.

# %% [markdown]
# ### 4.2 Exogeneity of age at arrival
#
# One assumption for using instrumental variable is that the instrument is as good as randomly assign and have no correlation with Y through other uncontrolled variables. The authors justify the exogeneity of age at arrival by stating that for childhood immigrants "age at arrival is not a choice variable since they did not time their own immigration, but merely come with their parents to the United State".
#
# We remain skeptical concerning the exogeneity assumption. Maybe the children are not the ones *making the final call* on the immigrate decision. However, we can reasonably think that the parents, if being responsible, will take *the children's ability to assimilate into considerations* when they are deciding to immigrate or not. If the parents know that their children will have a very rough time living in a new country, they have a higher cost and less probability to immigrate. This is more easily found in East Asian nations (which are non-English-speaking) where the offspring's future is weighted heavily. In addition, for the potentially-non-assimilating children who have already entered secondary school and are unwilling to move with their parents, the parents can just send the children to boarding school or leave the children to relatives in the origins, if they have a lower cost to do so.  So these non-assimilating children will not be included in the sample. This is more common in Asian or Middle-East countries (which are non-English-speaking) where family-collectivism is practiced. Siblings of the parents or grandparents have a larger moral responsibility to proxy the parents' role when the parents cannot take care of the children themselves.
#
# These family characteristics, when being uncontrolled for, create self-selection bias where children that are expected to have higher social outcomes will be taking the treatment. This will lead to an overestimation of the treatment effect.

# %% [markdown]
# ### 4.3 Cultural connotations in language
#
#
# As the authors remark in the paper, controlling the effect of mastering English (language effect) cannot exclude the effect of “melting” into the US culture and institution. The authors’ solution is to incorporate immigrants from the English speaking countries as the control group, so as to control for the non-language effect. They explain their decision:
#
# >*This is because, upon arrival in the United States, immigrants originating from English-speaking countries encounter everything that immigrants from non-English-speaking countries encounter except a new language. Thus, any difference in outcome between young and old arrivers from non-English-speaking countries that is over and above the difference from English-speaking countries can plausibly be attributed to language*. (Bleakley & Chin, 2010, p.169-170).
#
# Singling out the language effect on immigrants from non-anglophone countries certainly has a significant methodological merit, as anglophone immigrants barely come across any enormous language barrier. But it seems to us doubtful whether the authors can really separate the language effect and the culture effect.  Anglophone countries do not share the 100% same culture, however close they are.to each other. It is fairly possible that a British immigrant found the US metric system, jumbo-size Coca-Cola cups, and restaurant tipping manner very confusing. There can still be an influence of culture in the estimation of the parameters for the late-comers in treatment group.
#
# We differ our understanding of the meaning of the parameters estimated from the authors’. Instead of claiming that the difference in outcome is completely attributed to language, we can defend our thesis better by arguing that we have to take into account the embedded cultural effect in language, by looking at the nature of language. As Morris (1949) pointed out, a (natural) language is composed of three parts: semantics, syntax and pragmatics; Semantics refers to “the relations of signs to the objects to which the signs are applicable” are; Syntax refers to “the formal relation of signs to one another”; Pragmatics is “the relations of signs to interpreters”. The authors’ mistake, as it appears to us, is to assume language skill level has only the syntaxial aspect. While anglophone immigrants have not many obstacles in the syntax of English in America, they might have problems in the pragmatics of American English. For example, when a British says “Ooh, isn’t it cold?”, what he is doing (with his words) is to invite the listener to a conversation , but an American will just encode it as merely a question about weather.
#
# Figure 2. Relationship between language, culture and pragmatics
# <img src="Graph/Venn diagram.jpg" width="600">
#
# As it is shown by Wittgenstein (1967), “the speaking of language is part of an activity, or of a life-form”. Language is a social practice. When language users are interacting, the culture of the linguistic community is manifested. Culture is embedded in a language, through the pragmatics of it. Culture is instantiated in the language uses and culture-free language is not usable and empty. The language community, having their own culture, decide the rule of the “language game”, by which they determine who is a good speaker and who is not. In other words, to be a good language user, one has to know the culture of that linguistic community.
#
# In our estimation, we could not separate the cultures in the pragmatics side of English in America. But a comprehensive understanding of languages implies that we do not have to so do. Rather, it accepts the cultural aspect being part of the estimator of language level. And it includes the understanding of culture when interpreting the estimation of parameters.

# %% [markdown]
# ---
# # 5. Replication
# ---
#
# ### 5.1 Main result

# %% [markdown]
# We first estimate equation (2') which is a modification of equation (2). In equation (2') the dependent variable is a social outcome rather than English proficiency.
#
# \begin{equation}\tag{2'}
# Y_{ija}= \alpha_{1}+\pi_{1}k_{ija}+\delta_{1a}+\gamma_{1j}+W_{ija}'\rho_{1}+\epsilon_{1ija}
# \end{equation}
#
# Equation (2') is a reduced-form equation that returns the effect of age at arrival on social outcomes for the treatment group in a regression setting. From Table 2, we can observe that age-at-arrival is significant to the majority of variables the authors are interested in, except for some fertility and all location outcomes. In the benchmark, the age-at-arrival effects are to be explained through language proficiency. If this hypothesis is right, further regressions, given by equation (4) should verify that.

# %%
df_ind['eng'].replace('  ', np.nan, inplace=True)
df_ind= df_ind.dropna(subset=['eng'])
df_ind["pwlinear"] = np.where(df_ind.agearr>=9, df_ind["agearr"]-9 ,0)
df_ind["pwlinear"].describe()
df_ind["idvar"] = df_ind["pwlinear"]*df_ind["nengdom"]
df_ind["idvar"].describe() 
df_ind = (df_ind[df_ind.perwt2 !=0])

df_mat['eng'].replace('  ', np.nan, inplace=True)
df_mat= df_mat.dropna(subset=['eng'])
df_mat["young9"] = df_mat["agearr"] <=9
df_mat['eng'].replace('  ', np.nan, inplace=True)
df_mat= df_mat.dropna(subset=['eng'])
df_mat["pwlinear"] = np.where(df_mat.agearr>=9, df_mat["agearr"]-9 ,0)
df_mat["pwlinear"].describe()
df_mat["idvar"] = df_mat["pwlinear"]*df_mat["nengdom"]
df_mat["nchild_spouse"] = df_mat["nchild"]
df_mat["haskid_spouse"] = df_mat["haskid"]
df_ind["eng1"] = np.where(df_ind.eng>=1,1,0)
df_ind["eng2"] = np.where(df_ind.eng>=2,1,0)
df_ind["eng3"] = np.where(df_ind.eng>=3,1,0)
df_ind["tr9"] = df_ind["pwlinear"]*df_ind["nengdom"]
df_mat["tr9"] = df_mat["pwlinear"]*df_mat["nengdom"]
df_mat["nchild_spouse"] = df_mat["nchild"]
df_mat["haskid_spouse"] = df_mat["haskid"]

# %%
result_t2_ind = pd.DataFrame({"Dependent variable St": list_table2_ind})
for dep in list_table2_ind:
    get_table2_result(df_ind, dep, result_t2_ind)
result_t2_mat = pd.DataFrame({"Dependent variable St": list_table2_mat})
for dep in list_table2_mat:
    temp = get_table2_result(df_mat, dep, result_t2_mat)
result_table2 = result_t2_ind.append(result_t2_mat)


result_table2 =get_variable_full_name_table2(result_table2)
result_table2 = result_table2.sort_index(ascending=True)


get_asterisk(result_table2,"P Value", "Coef")
result_table2["Coefficient for identifying instrument variable"] = (result_table2["Parameter"].astype(str) + result_table2["Coef Sig. level"])
# Out:
# eng1
# eng2
# eng3
# eng
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse

# %%
result_table2= result_table2[["Coefficient for identifying instrument variable","SE"]]
print("Table 2—Reduced-Form Effects")
print("This table refers to Table 2 in the benchmark")

display(result_table2)
# Out:
# Table 2—Reduced-Form Effects
# This table refers to Table 2 in the benchmark
#                                                                                             Coefficient for identifying instrument variable  \
# Panel                                    Dependent variable
# Panel A. English proficiency measures    1. Speaks English not well or better                                                      -0.006**
#                                          2. Speaks English well or better                                                          -0.029**
#                                          3. Speaks English very well                                                              -0.069***
#                                          4. English-speaking ability ordinal measure                                              -0.104***
# Panel B. Marital status                  1. Is currently married with spouse present                                               0.011***
#                                          2. Is currently divorced                                                                 -0.005***
#                                          3. Has ever married                                                                       0.007***
# Panel C. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure                                       -0.086***
#                                          2. Spouse is US-born                                                                     -0.034***
#                                          3. Spouse has the same country of birth                                                   0.037***
#                                          4. Spouse has the same ancestry                                                             0.019*
# Panel D. Spouse’s age and education      1. Spouse age                                                                             0.096***
#                                          2. Spouse years of schooling                                                             -0.249***
# Panel E. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                                           -0.031***
#                                          2. Spouse worked last year                                                               -0.008***
#                                          3. Both worked last year                                                                  -0.013**
# Panel F. Fertility                       1. Number of children living in same household                                            0.046***
#                                          2. Has a child living in same household                                                     0.008*
#                                          3. Number of children living in same household,...                                        0.043***
#                                          4. Has a child living in same household, only i...                                          0.001
#                                          5. Is a single parent                                                                      -0.002
#                                          6. Is a never married, single parent                                                          0.0
# Panel G. Residential location            1. Fraction of PUMA population from same countr...                                          0.001
#                                          2. Fraction from same country of birth is above...                                          0.002
#                                          3. Fraction of PUMA population with same primar...                                          0.002
#                                          4. Fraction with same ancestry is above nationa...                                          0.002
#
#                                                                                                 SE
# Panel                                    Dependent variable
# Panel A. English proficiency measures    1. Speaks English not well or better                0.003
#                                          2. Speaks English well or better                    0.012
#                                          3. Speaks English very well                         0.013
#                                          4. English-speaking ability ordinal measure         0.029
# Panel B. Marital status                  1. Is currently married with spouse present         0.004
#                                          2. Is currently divorced                            0.002
#                                          3. Has ever married                                 0.003
# Panel C. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure  0.019
#                                          2. Spouse is US-born                                0.011
#                                          3. Spouse has the same country of birth             0.012
#                                          4. Spouse has the same ancestry                     0.011
# Panel D. Spouse’s age and education      1. Spouse age                                       0.035
#                                          2. Spouse years of schooling                        0.072
# Panel E. Spouse’s labor market outcomes  1. Spouse log(wages last year)                      0.012
#                                          2. Spouse worked last year                          0.003
#                                          3. Both worked last year                            0.005
# Panel F. Fertility                       1. Number of children living in same household      0.014
#                                          2. Has a child living in same household             0.004
#                                          3. Number of children living in same household,...  0.014
#                                          4. Has a child living in same household, only i...  0.002
#                                          5. Is a single parent                               0.003
#                                          6. Is a never married, single parent                0.002
# Panel G. Residential location            1. Fraction of PUMA population from same countr...  0.001
#                                          2. Fraction from same country of birth is above...  0.007
#                                          3. Fraction of PUMA population with same primar...  0.001
#                                          4. Fraction with same ancestry is above nationa...  0.006

# %% [markdown]
# The key results of the benchmark is replicated in table 3a, 3b and 3C, where we first look at the OLS and 2SLS results using equation (4) on the whole sample, male and female. English level, adjusted by the instrumental variable, affects most of the marital outcome. For example, the English skill level decreases the probability of being currently married. However, the effects on marital outcomes (that authors are interested in) do not tell a clear picture of the assimilation status of immigrants, which we explained earlier in the conceptual issues section.

# %%
#plot table 3 
df_ind_t3 = get_1st_stage_result(df_ind)
df_mat_t3 = get_1st_stage_result(df_mat)

result_table3_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
    get_ols_tsls_result(df_ind_t3, var, result_table3_ind)


result_table3_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
    get_ols_tsls_result(df_mat_t3, var, result_table3_mat)


result_table3 = result_table3_ind.append(result_table3_mat)
result_table3 = get_variable_full_name_table3(result_table3)
result_table3 = result_table3.sort_index(ascending=True)

get_asteris_and_coef(result_table3,"OLS P Value", "OLS", "English effect(OLS)") 
get_asteris_and_coef(result_table3,"2SLS P Value", "2SLS", "English effect(2SLS)")
# Out:
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse

# %%
print("Table 3a —Effect of English-Language Skills on Marriage Outcomes")
print("This table refers to the column (1) and (2) in Table (3),(4),(5) in the benchmark")

result_table3[["English effect(OLS)", "OLS SE" , "English effect(2SLS)", "2SLS SE", "2SLS Adj R sq"]]
# Out:
# Table 3a —Effect of English-Language Skills on Marriage Outcomes
# This table refers to the column (1) and (2) in Table (3),(4),(5) in the benchmark
#                                                                                             English effect(OLS)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                     0.008
#                                          2. Is currently divorced                                       0.01***
#                                          3. Has ever married                                            -0.002
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure            0.512***
#                                          2. Spouse is US-born                                          0.105***
#                                          3. Spouse has the same country of birth                       -0.12***
#                                          4. Spouse has the same ancestry                              -0.076***
# Panel C. Spouse’s age and education      1. Spouse age                                                -0.348***
#                                          2. Spouse years of schooling                                  1.353***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                0.169***
#                                          2. Spouse worked last year                                    0.039***
#                                          3. Both worked last year                                       0.09***
# Panel E. Fertility                       1. Number of children living in same household               -0.106***
#                                          2. Has a child living in same household                        -0.005
#                                          3. Number of children living in same household,...           -0.177***
#                                          4. Has a child living in same household, only i...           -0.019***
#                                          5. Is a single parent                                          -0.001
#                                          6. Is a never married, single parent                           -0.003
# Panel F. Residential location            1. Fraction of PUMA population from same countr...            -0.01***
#                                          2. Fraction from same country of birth is above...            -0.05***
#                                          3. Fraction of PUMA population with same primar...           -0.013***
#                                          4. Fraction with same ancestry is above nationa...           -0.041***
#
#                                                                                              OLS SE  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present          0.009
#                                          2. Is currently divorced                             0.003
#                                          3. Has ever married                                  0.007
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure   0.016
#                                          2. Spouse is US-born                                 0.009
#                                          3. Spouse has the same country of birth              0.007
#                                          4. Spouse has the same ancestry                      0.011
# Panel C. Spouse’s age and education      1. Spouse age                                        0.035
#                                          2. Spouse years of schooling                         0.034
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                       0.006
#                                          2. Spouse worked last year                           0.003
#                                          3. Both worked last year                             0.004
# Panel E. Fertility                       1. Number of children living in same household       0.021
#                                          2. Has a child living in same household              0.004
#                                          3. Number of children living in same household,...   0.013
#                                          4. Has a child living in same household, only i...   0.004
#                                          5. Is a single parent                                0.004
#                                          6. Is a never married, single parent                 0.002
# Panel F. Residential location            1. Fraction of PUMA population from same countr...   0.001
#                                          2. Fraction from same country of birth is above...   0.007
#                                          3. Fraction of PUMA population with same primar...   0.002
#                                          4. Fraction with same ancestry is above nationa...   0.007
#
#                                                                                             English effect(2SLS)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                   -0.108***
#                                          2. Is currently divorced                                       0.052***
#                                          3. Has ever married                                           -0.071***
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure             0.809***
#                                          2. Spouse is US-born                                           0.322***
#                                          3. Spouse has the same country of birth                       -0.351***
#                                          4. Spouse has the same ancestry                                  -0.18*
# Panel C. Spouse’s age and education      1. Spouse age                                                 -0.901***
#                                          2. Spouse years of schooling                                    2.35***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                 0.296***
#                                          2. Spouse worked last year                                     0.078***
#                                          3. Both worked last year                                         0.12**
# Panel E. Fertility                       1. Number of children living in same household                -0.441***
#                                          2. Has a child living in same household                        -0.073**
#                                          3. Number of children living in same household,...             -0.41***
#                                          4. Has a child living in same household, only i...              -0.007
#                                          5. Is a single parent                                            0.021
#                                          6. Is a never married, single parent                            -0.002
# Panel F. Residential location            1. Fraction of PUMA population from same countr...              -0.007
#                                          2. Fraction from same country of birth is above...              -0.015
#                                          3. Fraction of PUMA population with same primar...              -0.018
#                                          4. Fraction with same ancestry is above nationa...              -0.022
#
#                                                                                              2SLS SE  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present           0.039
#                                          2. Is currently divorced                              0.017
#                                          3. Has ever married                                   0.024
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure    0.180
#                                          2. Spouse is US-born                                  0.107
#                                          3. Spouse has the same country of birth               0.115
#                                          4. Spouse has the same ancestry                       0.099
# Panel C. Spouse’s age and education      1. Spouse age                                         0.334
#                                          2. Spouse years of schooling                          0.679
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                        0.111
#                                          2. Spouse worked last year                            0.029
#                                          3. Both worked last year                              0.048
# Panel E. Fertility                       1. Number of children living in same household        0.136
#                                          2. Has a child living in same household               0.037
#                                          3. Number of children living in same household,...    0.131
#                                          4. Has a child living in same household, only i...    0.020
#                                          5. Is a single parent                                 0.026
#                                          6. Is a never married, single parent                  0.017
# Panel F. Residential location            1. Fraction of PUMA population from same countr...    0.007
#                                          2. Fraction from same country of birth is above...    0.065
#                                          3. Fraction of PUMA population with same primar...    0.013
#                                          4. Fraction with same ancestry is above nationa...    0.057
#
#                                                                                              2SLS Adj R sq
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present              0.072147
#                                          2. Is currently divorced                                 0.036220
#                                          3. Has ever married                                      0.153013
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure       0.244451
#                                          2. Spouse is US-born                                     0.319407
#                                          3. Spouse has the same country of birth                  0.326626
#                                          4. Spouse has the same ancestry                          0.224261
# Panel C. Spouse’s age and education      1. Spouse age                                            0.727417
#                                          2. Spouse years of schooling                             0.265225
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                           0.193737
#                                          2. Spouse worked last year                               0.112868
#                                          3. Both worked last year                                 0.033702
# Panel E. Fertility                       1. Number of children living in same household           0.150791
#                                          2. Has a child living in same household                  0.120078
#                                          3. Number of children living in same household,...       0.165262
#                                          4. Has a child living in same household, only i...       0.101348
#                                          5. Is a single parent                                    0.061569
#                                          6. Is a never married, single parent                     0.034528
# Panel F. Residential location            1. Fraction of PUMA population from same countr...       0.448813
#                                          2. Fraction from same country of birth is above...       0.030742
#                                          3. Fraction of PUMA population with same primar...       0.357922
#                                          4. Fraction with same ancestry is above nationa...       0.024823

# %%
# plot table 3 female sample 
df_ind_t3_female = df_ind[df_ind["female"] == 1]
df_mat_t3_female = df_mat[df_mat["female"] == 1]

df_ind_t3_female = get_1st_stage_result(df_ind_t3_female)
df_mat_t3_female = get_1st_stage_result(df_mat_t3_female)


result_table3_female_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
    (temp_ols, temp_2SLS) = get_ols_tsls_result(df_ind_t3_female, var, result_table3_female_ind)


result_table3_female_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
    (temp_ols, temp_2SLS) = get_ols_tsls_result(df_mat_t3_female, var, result_table3_female_mat)


result_table3_female = result_table3_female_ind.append(result_table3_female_mat)

result_table3_female = get_variable_full_name_table3(result_table3_female)
result_table3_female = result_table3_female.sort_index(ascending=True, sort_remaining =False)


get_asteris_and_coef(result_table3_female,"OLS P Value", "OLS", "English effect(OLS)") 
get_asteris_and_coef(result_table3_female,"2SLS P Value", "2SLS", "English effect(2SLS)")
# Out:
# /Users/chingfungchow/Documents/GitHub/Microeconometrics-Paper/auxiliary.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['eng_hat'] = fit_st1.predict(data)
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse

# %%
print("Table 3b —Effect of English-Language Skills on Marriage Outcomes, female sample")
print("This table refers to the column (3) and (4) in Table (3),(4),(5) in the benchmark")
result_table3_female[["English effect(OLS)", "OLS SE" , "English effect(2SLS)", "2SLS SE", "2SLS Adj R sq"]]
# Out:
# Table 3b —Effect of English-Language Skills on Marriage Outcomes, female sample
# This table refers to the column (3) and (4) in Table (3),(4),(5) in the benchmark
#                                                                                             English effect(OLS)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                    -0.004
#                                          2. Is currently divorced                                      0.015***
#                                          3. Has ever married                                            -0.001
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure            0.474***
#                                          2. Spouse is US-born                                          0.101***
#                                          3. Spouse has the same country of birth                      -0.118***
#                                          4. Spouse has the same ancestry                              -0.078***
# Panel C. Spouse’s age and education      1. Spouse age                                                -0.496***
#                                          2. Spouse years of schooling                                  1.367***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                0.166***
#                                          2. Spouse worked last year                                    0.021***
#                                          3. Both worked last year                                      0.106***
# Panel E. Fertility                       1. Number of children living in same household               -0.162***
#                                          2. Has a child living in same household                      -0.019***
#                                          3. Number of children living in same household,...           -0.203***
#                                          4. Has a child living in same household, only i...           -0.024***
#                                          5. Is a single parent                                          -0.001
#                                          6. Is a never married, single parent                           -0.005
# Panel F. Residential location            1. Fraction of PUMA population from same countr...           -0.012***
#                                          2. Fraction from same country of birth is above...           -0.058***
#                                          3. Fraction of PUMA population with same primar...           -0.017***
#                                          4. Fraction with same ancestry is above nationa...            -0.05***
#
#                                                                                              OLS SE  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present          0.009
#                                          2. Is currently divorced                             0.003
#                                          3. Has ever married                                  0.005
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure   0.008
#                                          2. Spouse is US-born                                 0.011
#                                          3. Spouse has the same country of birth              0.009
#                                          4. Spouse has the same ancestry                      0.013
# Panel C. Spouse’s age and education      1. Spouse age                                        0.055
#                                          2. Spouse years of schooling                         0.036
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                       0.006
#                                          2. Spouse worked last year                           0.005
#                                          3. Both worked last year                             0.006
# Panel E. Fertility                       1. Number of children living in same household       0.019
#                                          2. Has a child living in same household              0.003
#                                          3. Number of children living in same household,...   0.017
#                                          4. Has a child living in same household, only i...   0.004
#                                          5. Is a single parent                                0.007
#                                          6. Is a never married, single parent                 0.004
# Panel F. Residential location            1. Fraction of PUMA population from same countr...   0.002
#                                          2. Fraction from same country of birth is above...   0.006
#                                          3. Fraction of PUMA population with same primar...   0.002
#                                          4. Fraction with same ancestry is above nationa...   0.007
#
#                                                                                             English effect(2SLS)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                    -0.076**
#                                          2. Is currently divorced                                        0.064**
#                                          3. Has ever married                                             -0.015
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure             0.615***
#                                          2. Spouse is US-born                                             0.27**
#                                          3. Spouse has the same country of birth                        -0.285**
#                                          4. Spouse has the same ancestry                                  -0.17
# Panel C. Spouse’s age and education      1. Spouse age                                                 -1.312***
#                                          2. Spouse years of schooling                                   2.188***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                  0.233**
#                                          2. Spouse worked last year                                       0.022
#                                          3. Both worked last year                                        0.12***
# Panel E. Fertility                       1. Number of children living in same household                -0.472***
#                                          2. Has a child living in same household                         -0.041
#                                          3. Number of children living in same household,...            -0.591***
#                                          4. Has a child living in same household, only i...               -0.02
#                                          5. Is a single parent                                            0.032
#                                          6. Is a never married, single parent                            -0.005
# Panel F. Residential location            1. Fraction of PUMA population from same countr...            -0.014***
#                                          2. Fraction from same country of birth is above...              -0.038
#                                          3. Fraction of PUMA population with same primar...            -0.033***
#                                          4. Fraction with same ancestry is above nationa...             -0.088**
#
#                                                                                              2SLS SE  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present           0.033
#                                          2. Is currently divorced                              0.027
#                                          3. Has ever married                                   0.027
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure    0.109
#                                          2. Spouse is US-born                                  0.118
#                                          3. Spouse has the same country of birth               0.127
#                                          4. Spouse has the same ancestry                       0.112
# Panel C. Spouse’s age and education      1. Spouse age                                         0.461
#                                          2. Spouse years of schooling                          0.592
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                        0.114
#                                          2. Spouse worked last year                            0.019
#                                          3. Both worked last year                              0.042
# Panel E. Fertility                       1. Number of children living in same household        0.128
#                                          2. Has a child living in same household               0.034
#                                          3. Number of children living in same household,...    0.140
#                                          4. Has a child living in same household, only i...    0.021
#                                          5. Is a single parent                                 0.033
#                                          6. Is a never married, single parent                  0.026
# Panel F. Residential location            1. Fraction of PUMA population from same countr...    0.004
#                                          2. Fraction from same country of birth is above...    0.046
#                                          3. Fraction of PUMA population with same primar...    0.006
#                                          4. Fraction with same ancestry is above nationa...    0.041
#
#                                                                                              2SLS Adj R sq
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present              0.062049
#                                          2. Is currently divorced                                 0.035673
#                                          3. Has ever married                                      0.136230
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure       0.232672
#                                          2. Spouse is US-born                                     0.340200
#                                          3. Spouse has the same country of birth                  0.338575
#                                          4. Spouse has the same ancestry                          0.226091
# Panel C. Spouse’s age and education      1. Spouse age                                            0.707548
#                                          2. Spouse years of schooling                             0.264124
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                           0.118192
#                                          2. Spouse worked last year                               0.027787
#                                          3. Both worked last year                                 0.027167
# Panel E. Fertility                       1. Number of children living in same household           0.165340
#                                          2. Has a child living in same household                  0.116814
#                                          3. Number of children living in same household,...       0.193076
#                                          4. Has a child living in same household, only i...       0.123443
#                                          5. Is a single parent                                    0.048728
#                                          6. Is a never married, single parent                     0.046236
# Panel F. Residential location            1. Fraction of PUMA population from same countr...       0.464532
#                                          2. Fraction from same country of birth is above...       0.036516
#                                          3. Fraction of PUMA population with same primar...       0.369076
#                                          4. Fraction with same ancestry is above nationa...       0.030300

# %%
# plot table 3 male sample 
df_ind_t3_male = df_ind[df_ind["female"] == 0]
df_mat_t3_male = df_mat[df_mat["female"] == 0]

df_ind_t3_male = get_1st_stage_result(df_ind_t3_male)
df_mat_t3_male = get_1st_stage_result(df_mat_t3_male)


result_table3_male_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
    (temp_ols, temp_2SLS) = get_ols_tsls_result(df_ind_t3_male, var, result_table3_male_ind)


result_table3_male_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
    (temp_ols, temp_2SLS) = get_ols_tsls_result(df_mat_t3_male, var, result_table3_male_mat)


result_table3_male = result_table3_male_ind.append(result_table3_male_mat)

result_table3_male = get_variable_full_name_table3(result_table3_male)
result_table3_male = result_table3_male.sort_index(ascending=True, sort_remaining =False)


get_asteris_and_coef(result_table3_male,"OLS P Value", "OLS", "English effect(OLS)") 
get_asteris_and_coef(result_table3_male,"2SLS P Value", "2SLS", "English effect(2SLS)")
# Out:
# /Users/chingfungchow/Documents/GitHub/Microeconometrics-Paper/auxiliary.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['eng_hat'] = fit_st1.predict(data)
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse

# %%
print("Table 3c —Effect of English-Language Skills on Marriage Outcomes, male sample")
print("This table refers to the column (5) and (6) in Table (3),(4),(5) in the benchmark")
result_table3_male[["English effect(OLS)", "OLS SE" , "English effect(2SLS)", "2SLS SE", "2SLS Adj R sq"]]
# Out:
# Table 3c —Effect of English-Language Skills on Marriage Outcomes, male sample
# This table refers to the column (5) and (6) in Table (3),(4),(5) in the benchmark
#                                                                                             English effect(OLS)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                     0.019*
#                                          2. Is currently divorced                                        0.006*
#                                          3. Has ever married                                            -0.004
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure             0.56***
#                                          2. Spouse is US-born                                          0.109***
#                                          3. Spouse has the same country of birth                      -0.122***
#                                          4. Spouse has the same ancestry                              -0.074***
# Panel C. Spouse’s age and education      1. Spouse age                                                -0.147***
#                                          2. Spouse years of schooling                                  1.343***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                0.172***
#                                          2. Spouse worked last year                                    0.062***
#                                          3. Both worked last year                                      0.072***
# Panel E. Fertility                       1. Number of children living in same household                 -0.049*
#                                          2. Has a child living in same household                         0.009
#                                          3. Number of children living in same household,...           -0.148***
#                                          4. Has a child living in same household, only i...           -0.014***
#                                          5. Is a single parent                                          -0.001
#                                          6. Is a never married, single parent                          -0.002**
# Panel F. Residential location            1. Fraction of PUMA population from same countr...           -0.008***
#                                          2. Fraction from same country of birth is above...           -0.041***
#                                          3. Fraction of PUMA population with same primar...           -0.009***
#                                          4. Fraction with same ancestry is above nationa...           -0.033***
#
#                                                                                              OLS SE  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present          0.011
#                                          2. Is currently divorced                             0.004
#                                          3. Has ever married                                  0.009
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure   0.027
#                                          2. Spouse is US-born                                 0.006
#                                          3. Spouse has the same country of birth              0.006
#                                          4. Spouse has the same ancestry                      0.009
# Panel C. Spouse’s age and education      1. Spouse age                                        0.033
#                                          2. Spouse years of schooling                         0.043
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                       0.012
#                                          2. Spouse worked last year                           0.004
#                                          3. Both worked last year                             0.004
# Panel E. Fertility                       1. Number of children living in same household       0.026
#                                          2. Has a child living in same household              0.007
#                                          3. Number of children living in same household,...   0.013
#                                          4. Has a child living in same household, only i...   0.004
#                                          5. Is a single parent                                0.001
#                                          6. Is a never married, single parent                 0.001
# Panel F. Residential location            1. Fraction of PUMA population from same countr...   0.001
#                                          2. Fraction from same country of birth is above...   0.009
#                                          3. Fraction of PUMA population with same primar...   0.001
#                                          4. Fraction with same ancestry is above nationa...   0.008
#
#                                                                                             English effect(2SLS)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                    -0.14***
#                                          2. Is currently divorced                                         0.038
#                                          3. Has ever married                                           -0.133***
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure             1.028***
#                                          2. Spouse is US-born                                           0.386***
#                                          3. Spouse has the same country of birth                       -0.434***
#                                          4. Spouse has the same ancestry                                -0.197**
# Panel C. Spouse’s age and education      1. Spouse age                                                   -0.382
#                                          2. Spouse years of schooling                                   2.582***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                  0.395**
#                                          2. Spouse worked last year                                      0.141**
#                                          3. Both worked last year                                         0.115*
# Panel E. Fertility                       1. Number of children living in same household                 -0.403**
#                                          2. Has a child living in same household                        -0.113**
#                                          3. Number of children living in same household,...               -0.19
#                                          4. Has a child living in same household, only i...               0.008
#                                          5. Is a single parent                                              0.0
#                                          6. Is a never married, single parent                            -0.008
# Panel F. Residential location            1. Fraction of PUMA population from same countr...                -0.0
#                                          2. Fraction from same country of birth is above...               0.007
#                                          3. Fraction of PUMA population with same primar...              -0.002
#                                          4. Fraction with same ancestry is above nationa...               0.056
#
#                                                                                              2SLS SE  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present           0.048
#                                          2. Is currently divorced                              0.023
#                                          3. Has ever married                                   0.046
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure    0.271
#                                          2. Spouse is US-born                                  0.110
#                                          3. Spouse has the same country of birth               0.104
#                                          4. Spouse has the same ancestry                       0.089
# Panel C. Spouse’s age and education      1. Spouse age                                         0.648
#                                          2. Spouse years of schooling                          0.848
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                        0.184
#                                          2. Spouse worked last year                            0.064
#                                          3. Both worked last year                              0.067
# Panel E. Fertility                       1. Number of children living in same household        0.165
#                                          2. Has a child living in same household               0.049
#                                          3. Number of children living in same household,...    0.183
#                                          4. Has a child living in same household, only i...    0.035
#                                          5. Is a single parent                                 0.015
#                                          6. Is a never married, single parent                  0.008
# Panel F. Residential location            1. Fraction of PUMA population from same countr...    0.011
#                                          2. Fraction from same country of birth is above...    0.091
#                                          3. Fraction of PUMA population with same primar...    0.021
#                                          4. Fraction with same ancestry is above nationa...    0.084
#
#                                                                                              2SLS Adj R sq
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present              0.092846
#                                          2. Is currently divorced                                 0.031216
#                                          3. Has ever married                                      0.164015
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure       0.259198
#                                          2. Spouse is US-born                                     0.310249
#                                          3. Spouse has the same country of birth                  0.326044
#                                          4. Spouse has the same ancestry                          0.229249
# Panel C. Spouse’s age and education      1. Spouse age                                            0.727247
#                                          2. Spouse years of schooling                             0.272656
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                           0.055268
#                                          2. Spouse worked last year                               0.042286
#                                          3. Both worked last year                                 0.041955
# Panel E. Fertility                       1. Number of children living in same household           0.133685
#                                          2. Has a child living in same household                  0.107167
#                                          3. Number of children living in same household,...       0.149393
#                                          4. Has a child living in same household, only i...       0.087784
#                                          5. Is a single parent                                    0.007007
#                                          6. Is a never married, single parent                     0.011830
# Panel F. Residential location            1. Fraction of PUMA population from same countr...       0.433569
#                                          2. Fraction from same country of birth is above...       0.026577
#                                          3. Fraction of PUMA population with same primar...       0.347328
#                                          4. Fraction with same ancestry is above nationa...       0.020615

# %% [markdown]
# The coefficients for “Spouse English-speaking ability”, “Spouse is US-born” and “Spouse has the same country of birth” are more direct indicators to an immigrant’s status: His or her English level moves in the same direction with the spouse English ability and the probability of the spouse being US-born, and it moves in the opposite direction with the probability of marrying someone from the same country of birth. These results imply that English level helps an immigrant to depart from the social circle of his or her countrypeople and be able to build relationships, in one most intimate form, with the US locals. Similarly, English also improves the spouse labor outcome, such as wage and employment status. It is worth noticing that for female immigrants, higher English level statistically significantly decreases the age of their spouses, while we do not observe a significant effect for male respondents.
#
# English level does not bring significant effects to fertility outcomes, except for the decrease in the number of children. It might be caused by the fact that the mean age in the treatment group (36.54) is slightly less than that in the control group (38.403). In addition, English skills bear no demonstrative improvement in ethnic enclaving or resident location outcomes. The technicality issue is that due to data privacy, the lowest level of geographic aggregation measure “public-use microdata area” (PUMA), which is an area containing at least 100,000 people. As a result, our definition for a neighborhood becomes too big, leading to the unsatisfactory theoretical ground for our estimation.
#
# However, in the authors’ analysis, the adjusted R-square of each estimation is not presented. As soon as we pay attention to the goodness-of-fit, we discover that equation (4) does a poor job in giving precise predictions. 2SLS estimations on an outcome such as “is currently married with spouse present”, “is currently divorced”, “has a child living in the same household”, “is a single parent” and “spouse worked last year” have an adjusted R-squared less than 0.04, which as a sign that there is just too much residual. The poor goodness-of-fit of the outcome with currently married (or divorced) might be consistent with our previous analysis. The effect of English on an immigrant’s decision on marriage is ambiguous, as there are reasonable theories to predict the opposite results.

# %% [markdown]
# ### 5.2 Robustness checks in the benchmark

# %% [markdown]
# It is possible that in table 3a,3b and 3c there are uncontrol features for the treatment group (childhood immigrants from non-English-speaking countries) that will be included in the 2SLS estimator. The authors consider alternative hypotheses for robustness check, in order to eliminate the non-language effect in the estimations. The robustness checks done by the authors are summarized in table 4a. The results in alternative specifications, as shown in table 4b, are similar to the baseline 2SLS analysis.

# %% [markdown]
# Table 4a — Summary of robustness check in the benchmark: Feature, movitivation and solution
# <img src="Graph/TableRobustness.jpg" width="800">

# %%
####################get baseline result (from table 3 )

result_table4_baseline = result_table3[["English effect(2SLS)", "2SLS SE"]]
# result_table4_baseline = result_table4_baseline.rename(columns={"English effect(2SLS)":"Base results (1)","2SLS SE":"2SLS SE"},inplace = True)

####################get result with control in origin's GDP
df_ind_GDP = df_ind
df_mat_GDP = df_mat


df_ind_GDP['lngdp'].replace('  ', np.nan, inplace=True)
df_ind_GDP= df_ind_GDP.dropna(subset=['lngdp'])
df_mat_GDP['lngdp'].replace('  ', np.nan, inplace=True)
df_mat_GDP= df_mat_GDP.dropna(subset=['lngdp'])

df_ind_GDP["pwxgdp"]=(df_ind_GDP["pwlinear"]*df_ind_GDP["lngdp"])/100
df_mat_GDP["pwxgdp"]=(df_mat_GDP["pwlinear"]*df_mat_GDP["lngdp"])/100

df_ind_GDP = get_first_stage_result_table4(df_ind_GDP ,"pwxgdp" )
df_mat_GDP = get_first_stage_result_table4(df_mat_GDP, "pwxgdp")


result_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
    (temp_2SLS) = get_tsls_result_table4(df_ind_GDP, var, result_ind,"pwxgdp")

result_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
    (temp_2SLS) = get_tsls_result_table4(df_mat_GDP, var, result_mat,"pwxgdp")

result_table4_control_GDP = result_ind.append(result_mat)


result_table4_control_GDP = get_variable_full_name_table3(result_table4_control_GDP)
get_asteris_and_coef(result_table4_control_GDP,"2SLS P Value", "2SLS", "Control for origin GDP × age at arrival (2)") 
result_table4_control_GDP = result_table4_control_GDP[["Control for origin GDP × age at arrival (2)", "2SLS SE"]]


####################get result with control in origin's fertility
df_ind_tfr = df_ind
df_mat_tfr = df_mat

df_ind_tfr['tfr82'].replace('  ', np.nan, inplace=True)
df_ind_tfr= df_ind_tfr.dropna(subset=['tfr82'])

df_mat_tfr['tfr82'].replace('  ', np.nan, inplace=True)
df_mat_tfr= df_mat_tfr.dropna(subset=['tfr82'])

df_ind_tfr["pwxtfr"]=(df_ind_tfr["pwlinear"]*df_ind_tfr["tfr82"])
df_mat_tfr["pwxtfr"]=(df_mat_tfr["pwlinear"]*df_mat_tfr["tfr82"])

df_ind_tfr = get_first_stage_result_table4(df_ind_tfr ,"pwxtfr" )
df_mat_tfr = get_first_stage_result_table4(df_mat_tfr, "pwxtfr")


result_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
    (temp_2SLS) = get_tsls_result_table4(df_ind_tfr, var, result_ind,"pwxtfr")

result_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
    (temp_2SLS) = get_tsls_result_table4(df_mat_tfr, var, result_mat,"pwxtfr")

result_table4_control_fertility = result_ind.append(result_mat)
result_table4_control_fertility = get_variable_full_name_table3(result_table4_control_fertility)
get_asteris_and_coef(result_table4_control_fertility,"2SLS P Value", "2SLS", "Control for origin fertility × age at arrival (3)") 
result_table4_control_fertility = result_table4_control_fertility[["Control for origin fertility × age at arrival (3)", "2SLS SE"]]

####################get result dropping immigrants from Canada
df_ind_no_CA = df_ind

df_mat_no_CA = df_mat

df_ind_no_CA = (df_ind_no_CA[df_ind_no_CA.bpld !=15000])
df_mat_no_CA = (df_mat_no_CA[df_mat_no_CA.bpld !=15000])

df_ind_no_CA = get_first_stage_result_table4(df_ind_no_CA  )
df_mat_no_CA = get_first_stage_result_table4(df_mat_no_CA)


result_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
    (temp_2SLS) = get_tsls_result_table4(df_ind_no_CA, var, result_ind)

result_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
    (temp_2SLS) = get_tsls_result_table4(df_mat_no_CA, var, result_mat)

result_table4_no_CA = result_ind.append(result_mat)
result_table4_no_CA = get_variable_full_name_table3(result_table4_no_CA)
get_asteris_and_coef(result_table4_no_CA,"2SLS P Value", "2SLS", "Drop Canada (4)") 
result_table4_no_CA = result_table4_no_CA[["Drop Canada (4)", "2SLS SE"]]


####################get result dropping immigrants from Mexico
df_ind_no_Mex = df_ind

df_mat_no_Mex = df_mat

df_ind_no_Mex = (df_ind_no_Mex[df_ind_no_Mex.bpld !=20000])
df_mat_no_Mex = (df_mat_no_Mex[df_mat_no_Mex.bpld !=20000])
df_ind_no_Mex = get_first_stage_result_table4(df_ind_no_Mex)
df_mat_no_Mex = get_first_stage_result_table4(df_mat_no_Mex)

result_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
    (temp_2SLS) = get_tsls_result_table4(df_ind_no_Mex, var, result_ind)

result_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
    (temp_2SLS) = get_tsls_result_table4(df_mat_no_Mex, var, result_mat)

result_table4_no_Mex = result_ind.append(result_mat)

result_table4_no_Mex = get_variable_full_name_table3(result_table4_no_Mex)
get_asteris_and_coef(result_table4_no_Mex,"2SLS P Value", "2SLS", "Drop Mexico (5)") 
result_table4_no_Mex = result_table4_no_Mex[["Drop Mexico (5)", "2SLS SE"]]
result_table4_no_Mex



result_table4_baseline=result_table4_baseline.rename(columns={ "English effect(2SLS)":"Base results (1)", "2SLS SE": "SE(1)"})
result_table4_control_GDP=result_table4_control_GDP.rename(columns={"2SLS SE": "SE(2)"})
result_table4_control_fertility=result_table4_control_fertility.rename(columns={"2SLS SE": "SE(3)"})
result_table4_no_CA=result_table4_no_CA.rename(columns={"2SLS SE": "SE(4)"})
result_table4_no_Mex=result_table4_no_Mex.rename(columns={"2SLS SE": "SE(5)"})


result_table4 = pd.merge(result_table4_baseline, result_table4_control_GDP,
                        left_on=["Panel",'Dependent variable'], right_on = ["Panel",'Dependent variable'], how = 'left')
result_table4 = pd.merge(result_table4, result_table4_control_fertility,
                       left_on=["Panel",'Dependent variable'], right_on = ["Panel",'Dependent variable'], how = 'left')
result_table4 = pd.merge(result_table4, result_table4_no_CA,
                       left_on=["Panel",'Dependent variable'], right_on = ["Panel",'Dependent variable'], how = 'left')
result_table4 = pd.merge(result_table4, result_table4_no_Mex,
                       left_on=["Panel",'Dependent variable'], right_on = ["Panel",'Dependent variable'], how = 'left')

result_table4 = result_table4.sort_index(ascending=True, sort_remaining =False)
# Out:
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/chingfungchow/Documents/GitHub/Microeconometrics-Paper/auxiliary.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['eng_hat'] = fit_st1.predict(data)
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse
# /Users/chingfungchow/Documents/GitHub/Microeconometrics-Paper/auxiliary.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['eng_hat'] = fit_st1.predict(data)
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse

# %%
print("Table 4b — 2SLS Effect of English Using Alternative Samples and Specifications")
print("This table refers to Table (6) in the benchmark")
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(result_table4)
# Out:
# Table 4b — 2SLS Effect of English Using Alternative Samples and Specifications
# This table refers to Table (6) in the benchmark
#                                                                                             Base results (1)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present               -0.108***
#                                          2. Is currently divorced                                   0.052***
#                                          3. Has ever married                                       -0.071***
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure         0.809***
#                                          2. Spouse is US-born                                       0.322***
#                                          3. Spouse has the same country of birth                   -0.351***
#                                          4. Spouse has the same ancestry                              -0.18*
# Panel C. Spouse’s age and education      1. Spouse age                                             -0.901***
#                                          2. Spouse years of schooling                                2.35***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                             0.296***
#                                          2. Spouse worked last year                                 0.078***
#                                          3. Both worked last year                                     0.12**
# Panel E. Fertility                       1. Number of children living in same household            -0.441***
#                                          2. Has a child living in same household                    -0.073**
#                                          3. Number of children living in same household,...         -0.41***
#                                          4. Has a child living in same household, only i...          -0.007
#                                          5. Is a single parent                                        0.021
#                                          6. Is a never married, single parent                        -0.002
# Panel F. Residential location            1. Fraction of PUMA population from same countr...          -0.007
#                                          2. Fraction from same country of birth is above...          -0.015
#                                          3. Fraction of PUMA population with same primar...          -0.018
#                                          4. Fraction with same ancestry is above nationa...          -0.022
#
#                                                                                              SE(1)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present         0.039
#                                          2. Is currently divorced                            0.017
#                                          3. Has ever married                                 0.024
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure  0.180
#                                          2. Spouse is US-born                                0.107
#                                          3. Spouse has the same country of birth             0.115
#                                          4. Spouse has the same ancestry                     0.099
# Panel C. Spouse’s age and education      1. Spouse age                                       0.334
#                                          2. Spouse years of schooling                        0.679
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                      0.111
#                                          2. Spouse worked last year                          0.029
#                                          3. Both worked last year                            0.048
# Panel E. Fertility                       1. Number of children living in same household      0.136
#                                          2. Has a child living in same household             0.037
#                                          3. Number of children living in same household,...  0.131
#                                          4. Has a child living in same household, only i...  0.020
#                                          5. Is a single parent                               0.026
#                                          6. Is a never married, single parent                0.017
# Panel F. Residential location            1. Fraction of PUMA population from same countr...  0.007
#                                          2. Fraction from same country of birth is above...  0.065
#                                          3. Fraction of PUMA population with same primar...  0.013
#                                          4. Fraction with same ancestry is above nationa...  0.057
#
#                                                                                             Control for origin GDP × age at arrival (2)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                                           -0.082**
#                                          2. Is currently divorced                                                              0.051***
#                                          3. Has ever married                                                                    -0.043*
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure                                    0.752***
#                                          2. Spouse is US-born                                                                  0.261***
#                                          3. Spouse has the same country of birth                                              -0.285***
#                                          4. Spouse has the same ancestry                                                        -0.091
# Panel C. Spouse’s age and education      1. Spouse age                                                                        -0.913***
#                                          2. Spouse years of schooling                                                          2.295***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                                         0.277**
#                                          2. Spouse worked last year                                                             0.069**
#                                          3. Both worked last year                                                               0.114**
# Panel E. Fertility                       1. Number of children living in same household                                       -0.399***
#                                          2. Has a child living in same household                                                -0.041
#                                          3. Number of children living in same household,...                                   -0.397***
#                                          4. Has a child living in same household, only i...                                      0.004
#                                          5. Is a single parent                                                                   0.034*
#                                          6. Is a never married, single parent                                                    0.008
# Panel F. Residential location            1. Fraction of PUMA population from same countr...                                        0.0
#                                          2. Fraction from same country of birth is above...                                      0.022
#                                          3. Fraction of PUMA population with same primar...                                     -0.008
#                                          4. Fraction with same ancestry is above nationa...                                      0.031
#
#                                                                                              SE(2)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present         0.037
#                                          2. Is currently divorced                            0.017
#                                          3. Has ever married                                 0.023
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure  0.194
#                                          2. Spouse is US-born                                0.074
#                                          3. Spouse has the same country of birth             0.090
#                                          4. Spouse has the same ancestry                     0.057
# Panel C. Spouse’s age and education      1. Spouse age                                       0.289
#                                          2. Spouse years of schooling                        0.722
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                      0.108
#                                          2. Spouse worked last year                          0.029
#                                          3. Both worked last year                            0.049
# Panel E. Fertility                       1. Number of children living in same household      0.149
#                                          2. Has a child living in same household             0.028
#                                          3. Number of children living in same household,...  0.134
#                                          4. Has a child living in same household, only i...  0.018
#                                          5. Is a single parent                               0.020
#                                          6. Is a never married, single parent                0.014
# Panel F. Residential location            1. Fraction of PUMA population from same countr...  0.003
#                                          2. Fraction from same country of birth is above...  0.053
#                                          3. Fraction of PUMA population with same primar...  0.010
#                                          4. Fraction with same ancestry is above nationa...  0.044
#
#                                                                                             Control for origin fertility × age at arrival (3)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                                                 -0.097**
#                                          2. Is currently divorced                                                                    0.053***
#                                          3. Has ever married                                                                         -0.057**
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure                                          0.817***
#                                          2. Spouse is US-born                                                                        0.368***
#                                          3. Spouse has the same country of birth                                                    -0.389***
#                                          4. Spouse has the same ancestry                                                               -0.21
# Panel C. Spouse’s age and education      1. Spouse age                                                                                 -1.1**
#                                          2. Spouse years of schooling                                                                2.424***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                                              0.336***
#                                          2. Spouse worked last year                                                                   0.062**
#                                          3. Both worked last year                                                                     0.102**
# Panel E. Fertility                       1. Number of children living in same household                                             -0.349***
#                                          2. Has a child living in same household                                                      -0.058
#                                          3. Number of children living in same household,...                                         -0.326***
#                                          4. Has a child living in same household, only i...                                           -0.003
#                                          5. Is a single parent                                                                         0.025
#                                          6. Is a never married, single parent                                                          0.001
# Panel F. Residential location            1. Fraction of PUMA population from same countr...                                           -0.014
#                                          2. Fraction from same country of birth is above...                                           -0.035
#                                          3. Fraction of PUMA population with same primar...                                          -0.032**
#                                          4. Fraction with same ancestry is above nationa...                                           -0.032
#
#                                                                                              SE(3)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present         0.043
#                                          2. Is currently divorced                            0.019
#                                          3. Has ever married                                 0.028
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure  0.131
#                                          2. Spouse is US-born                                0.136
#                                          3. Spouse has the same country of birth             0.141
#                                          4. Spouse has the same ancestry                     0.128
# Panel C. Spouse’s age and education      1. Spouse age                                       0.451
#                                          2. Spouse years of schooling                        0.556
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                      0.118
#                                          2. Spouse worked last year                          0.029
#                                          3. Both worked last year                            0.042
# Panel E. Fertility                       1. Number of children living in same household      0.110
#                                          2. Has a child living in same household             0.042
#                                          3. Number of children living in same household,...  0.116
#                                          4. Has a child living in same household, only i...  0.032
#                                          5. Is a single parent                               0.032
#                                          6. Is a never married, single parent                0.021
# Panel F. Residential location            1. Fraction of PUMA population from same countr...  0.011
#                                          2. Fraction from same country of birth is above...  0.062
#                                          3. Fraction of PUMA population with same primar...  0.014
#                                          4. Fraction with same ancestry is above nationa...  0.057
#
#                                                                                             Drop Canada (4)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present               -0.108**
#                                          2. Is currently divorced                                   0.049**
#                                          3. Has ever married                                       -0.071**
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure        0.797***
#                                          2. Spouse is US-born                                       0.224**
#                                          3. Spouse has the same country of birth                   -0.278**
#                                          4. Spouse has the same ancestry                            -0.144
# Panel C. Spouse’s age and education      1. Spouse age                                             -0.978**
#                                          2. Spouse years of schooling                              2.273***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                              0.23**
#                                          2. Spouse worked last year                                  0.062*
#                                          3. Both worked last year                                     0.1**
# Panel E. Fertility                       1. Number of children living in same household           -0.414***
#                                          2. Has a child living in same household                    -0.058
#                                          3. Number of children living in same household,...       -0.383***
#                                          4. Has a child living in same household, only i...          0.011
#                                          5. Is a single parent                                       0.033
#                                          6. Is a never married, single parent                        0.005
# Panel F. Residential location            1. Fraction of PUMA population from same countr...         -0.005
#                                          2. Fraction from same country of birth is above...          0.018
#                                          3. Fraction of PUMA population with same primar...         -0.016
#                                          4. Fraction with same ancestry is above nationa...         -0.005
#
#                                                                                              SE(4)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present         0.047
#                                          2. Is currently divorced                            0.021
#                                          3. Has ever married                                 0.029
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure  0.178
#                                          2. Spouse is US-born                                0.096
#                                          3. Spouse has the same country of birth             0.130
#                                          4. Spouse has the same ancestry                     0.122
# Panel C. Spouse’s age and education      1. Spouse age                                       0.439
#                                          2. Spouse years of schooling                        0.725
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                      0.112
#                                          2. Spouse worked last year                          0.032
#                                          3. Both worked last year                            0.048
# Panel E. Fertility                       1. Number of children living in same household      0.144
#                                          2. Has a child living in same household             0.043
#                                          3. Number of children living in same household,...  0.136
#                                          4. Has a child living in same household, only i...  0.018
#                                          5. Is a single parent                               0.027
#                                          6. Is a never married, single parent                0.020
# Panel F. Residential location            1. Fraction of PUMA population from same countr...  0.007
#                                          2. Fraction from same country of birth is above...  0.060
#                                          3. Fraction of PUMA population with same primar...  0.013
#                                          4. Fraction with same ancestry is above nationa...  0.055
#
#                                                                                             Drop Mexico (5)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present               -0.159**
#                                          2. Is currently divorced                                   0.071**
#                                          3. Has ever married                                       -0.115**
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure        1.023***
#                                          2. Spouse is US-born                                      0.593***
#                                          3. Spouse has the same country of birth                  -0.591***
#                                          4. Spouse has the same ancestry                          -0.498***
# Panel C. Spouse’s age and education      1. Spouse age                                             -1.493**
#                                          2. Spouse years of schooling                              2.745***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                             0.374**
#                                          2. Spouse worked last year                                  0.088*
#                                          3. Both worked last year                                    0.111*
# Panel E. Fertility                       1. Number of children living in same household           -0.476***
#                                          2. Has a child living in same household                    -0.113*
#                                          3. Number of children living in same household,...       -0.433***
#                                          4. Has a child living in same household, only i...         -0.008
#                                          5. Is a single parent                                        0.01
#                                          6. Is a never married, single parent                       -0.009
# Panel F. Residential location            1. Fraction of PUMA population from same countr...        -0.027**
#                                          2. Fraction from same country of birth is above...        -0.19***
#                                          3. Fraction of PUMA population with same primar...       -0.063***
#                                          4. Fraction with same ancestry is above nationa...       -0.184***
#
#                                                                                              SE(5)
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present         0.069
#                                          2. Is currently divorced                            0.029
#                                          3. Has ever married                                 0.047
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure  0.105
#                                          2. Spouse is US-born                                0.213
#                                          3. Spouse has the same country of birth             0.218
#                                          4. Spouse has the same ancestry                     0.193
# Panel C. Spouse’s age and education      1. Spouse age                                       0.678
#                                          2. Spouse years of schooling                        0.696
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                      0.174
#                                          2. Spouse worked last year                          0.046
#                                          3. Both worked last year                            0.059
# Panel E. Fertility                       1. Number of children living in same household      0.150
#                                          2. Has a child living in same household             0.064
#                                          3. Number of children living in same household,...  0.143
#                                          4. Has a child living in same household, only i...  0.046
#                                          5. Is a single parent                               0.045
#                                          6. Is a never married, single parent                0.031
# Panel F. Residential location            1. Fraction of PUMA population from same countr...  0.012
#                                          2. Fraction from same country of birth is above...  0.067
#                                          3. Fraction of PUMA population with same primar...  0.013
#                                          4. Fraction with same ancestry is above nationa...  0.056

# %% [markdown]
# ---
# # 6. Robustness checks and extensions
# ---

# %% [markdown]
# ### 6.1 Durbin Wu Hausman test

# %% [markdown]
# We first examine the endogeneity of English proficiency, or in other words, whether employing IV add merits to our analysis. Although the benchmark authors test for endogeneity by comparing OLS and IV estimate, we can also test for endogeneity in a more formal way by running the Durbin–Wu–Hausman test on English proficiency.
#
# As stated before, our equation (2) is:
# \begin{equation}\tag{2}
# ENG_{ija}= \alpha_{1}+\pi_{1}k_{ija}+\delta_{1a}+\gamma_{1j}+W_{ija}'\rho_{1}+\epsilon_{1ija}
# \end{equation}
#
# By equation (2), we get the estimation of $\epsilon_{1ija}$ ie. $\hat{\epsilon_{1ija}}$
#
#
# Durbin–Wu–Hausman test result given by
#
# \begin{equation}\tag{5}
# y_{ija}= \alpha_{1}+ \beta {ENG_{ija}}+ \omega\hat{\epsilon_{ija}} + \delta_{a}+\gamma_{j}  + W_{ija}'\rho + \mu_{ija}
# \end{equation}
#
# The estimation of $\omega$ will be our target.

# %%
#DWH Test

fit_st1 = wls( "eng ~ idvar + C(agearr) + C(age) + C(bpld) + female + black + asianpi + other + multi + hispdum", data=df_ind, weights=df_ind["perwt2"] ).fit(cov_type='cluster', cov_kwds={'groups': df_ind['bpld']}, use_t=False)
df_ind['Epsilon']  = fit_st1.resid
df_ind['eng_hat'] = fit_st1.predict(df_ind)


result_DWH_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
for var in list_table3_ind:
   get_Durbin_Wu_Hausman_result(df_ind, var,result_DWH_ind )
fit_st1 = wls( "eng ~ idvar + C(agearr) + C(age) + C(bpld) + female + black + asianpi + other + multi + hispdum", data=df_mat, weights=df_mat["perwt2"] ).fit(cov_type='cluster', cov_kwds={'groups': df_mat['bpld']}, use_t=False)
df_mat['Epsilon']  = fit_st1.resid
df_mat['eng_hat'] = fit_st1.predict(df_mat)


result_DWH_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
for var in list_table3_mat:
   get_Durbin_Wu_Hausman_result(df_mat, var,result_DWH_mat )
result_DWH = result_DWH_ind.append(result_DWH_mat)
result_DWH = get_variable_full_name_table3(result_DWH)
result_DWH = result_DWH.sort_index(ascending=True, sort_remaining =False)

get_asteris_and_coef(result_DWH,"Epsilon P Value", "Epsilon", "Epsilon") 

result_DWH=result_DWH[["Epsilon","Epsilon SE"]]
# Out:
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse

# %%
print("Table 5 —Durbin Wu Hausman test result")
result_DWH
# Out:
# Table 5 —Durbin Wu Hausman test result
#                                                                                                Epsilon  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present          0.117***
#                                          2. Is currently divorced                            -0.043***
#                                          3. Has ever married                                   0.07***
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure  -0.303***
#                                          2. Spouse is US-born                                  -0.22**
#                                          3. Spouse has the same country of birth               0.234**
#                                          4. Spouse has the same ancestry                        0.106
# Panel C. Spouse’s age and education      1. Spouse age                                          0.558*
#                                          2. Spouse years of schooling                        -1.022***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                        -0.131
#                                          2. Spouse worked last year                             -0.04*
#                                          3. Both worked last year                              -0.032
# Panel E. Fertility                       1. Number of children living in same household       0.339***
#                                          2. Has a child living in same household                0.069*
#                                          3. Number of children living in same household,...   0.235***
#                                          4. Has a child living in same household, only i...    -0.012
#                                          5. Is a single parent                                 -0.022
#                                          6. Is a never married, single parent                  -0.001
# Panel F. Residential location            1. Fraction of PUMA population from same countr...    -0.003
#                                          2. Fraction from same country of birth is above...    -0.035
#                                          3. Fraction of PUMA population with same primar...     0.005
#                                          4. Fraction with same ancestry is above nationa...     -0.02
#
#                                                                                              Epsilon SE
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present              0.036
#                                          2. Is currently divorced                                 0.016
#                                          3. Has ever married                                      0.023
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure       0.032
#                                          2. Spouse is US-born                                     0.104
#                                          3. Spouse has the same country of birth                  0.108
#                                          4. Spouse has the same ancestry                          0.104
# Panel C. Spouse’s age and education      1. Spouse age                                            0.329
#                                          2. Spouse years of schooling                             0.348
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                           0.086
#                                          2. Spouse worked last year                               0.024
#                                          3. Both worked last year                                 0.031
# Panel E. Fertility                       1. Number of children living in same household           0.100
#                                          2. Has a child living in same household                  0.036
#                                          3. Number of children living in same household,...       0.081
#                                          4. Has a child living in same household, only i...       0.020
#                                          5. Is a single parent                                    0.024
#                                          6. Is a never married, single parent                     0.017
# Panel F. Residential location            1. Fraction of PUMA population from same countr...       0.010
#                                          2. Fraction from same country of birth is above...       0.072
#                                          3. Fraction of PUMA population with same primar...       0.017
#                                          4. Fraction with same ancestry is above nationa...       0.062

# %% [markdown]
# The test evaluate the endogeneity of English proficiency by verifying the economic and statistics significance of the coefficient for epsilon hat. If $\hat{\omega}$ is significant, it is implied that that endogenous regressors' effects on the estimates are significant, and an IV strategy is needed. Vice versa, if residual is not statistically significantly different from zero, so conclude that there is no endogeneity bias in the OLS estimates. Using DWH test, we discovered that with regard to quite a lot of outcomes, we have no statistical reasons to use English proficiency as the instrument. The exceptions are “Spouse English-speaking ability ordinal measure”, “Spouse years of schooling” , “Spouse age”, “Number of children living in same household”.
#
# However, although the DWH test result is not satisfactory, we might still defend using this IV approach by arguing an "economics theory comes first" attitude. The statistical failure is a result caused by the imperfectness of the data on hand and possibly committing variable biases. As long as the economics reasoning is backed by a strong economics theory and intuition, we should feel confident employing the current IV.

# %% [markdown]
# ### 6.2 Control for residence location

# %% [markdown]
# It is known that different states have different cultures and policies, and therefore different acceptance towards immigrants. Some states have an immigrant tradition such as Los Angeles and New York while some do not. It is possible that some locations of residence are more popular within non-English-speaking immigrants. For example, California has a lot of Asian immigrants because of the location and its immigrant heritage. Likewise, Mexican and South American immigrants are clustered in southern states such as Texas, New Mexico and Florida. States with a stronger immigrants heritage are easier for immigrants to assimilate. So the result might be biased. We therefore include a vector of dummy variables of state of residence and interaction between birthplace and state of residence into the model.

# %%
result_R2_ind = pd.DataFrame({"Dependent variable St": list_table3_ind})
fit_st1 = wls( "eng ~ idvar + C(agearr) + C(age) + C(bpld)+ C(statefip)*pwlinear + female + black + asianpi + other + multi + hispdum", data=df_ind, weights=df_ind["perwt2"] ).fit(cov_type='cluster', cov_kwds={'groups': df_ind['bpld']}, use_t=False)
df_ind['eng_hat'] = fit_st1.predict(df_ind)

for var in list_table3_ind:
    get_ols_tsls_result_Robust2(df_ind, var, result_R2_ind)

result_R2_mat = pd.DataFrame({"Dependent variable St": list_table3_mat})
fit_st1 = wls( "eng ~ idvar + C(agearr) + C(age) + C(bpld)+ C(statefip)*pwlinear + female + black + asianpi + other + multi + hispdum", data=df_mat, weights=df_mat["perwt2"] ).fit(cov_type='cluster', cov_kwds={'groups': df_mat['bpld']}, use_t=False)
df_mat['eng_hat'] = fit_st1.predict(df_mat)

for var in list_table3_mat:
    get_ols_tsls_result_Robust2(df_mat, var, result_R2_mat)


result_R2 = result_R2_ind.append(result_R2_mat)
result_R2 = get_variable_full_name_table3(result_R2)
result_R2 = result_R2.sort_index(ascending=True, sort_remaining =False)
get_asteris_and_coef(result_R2,"2SLS P Value", "2SLS", "English effect(2SLS)") 
   
result_R2 = result_R2[["English effect(2SLS)", "2SLS SE"]]
# Out:
# marriedpresent
# divorced
# evermarried
# nchild
# haskid
# singleparent
# nevermarried_haskid
# share_bpld_minusself
# abovemean_bpld2
# ancestpct_minusself
# abovemean_ancestry2
# spouseeng
# marriednative
# couplesamebpld
# couplesameancestry1
# spouseage
# spouseyrssch
# spouselnwage
# spouseworkedly
# bothworked
# nchild_spouse
# haskid_spouse

# %%
print("Table 6 — English effect with control on the residence location (state level)")
result_R2
# Out:
# Table 6 — English effect with control on the residence location (state level)
#                                                                                             English effect(2SLS)  \
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present                    -0.096**
#                                          2. Is currently divorced                                         0.05**
#                                          3. Has ever married                                           -0.077***
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure             0.852***
#                                          2. Spouse is US-born                                           0.385***
#                                          3. Spouse has the same country of birth                       -0.403***
#                                          4. Spouse has the same ancestry                                -0.225**
# Panel C. Spouse’s age and education      1. Spouse age                                                 -1.085***
#                                          2. Spouse years of schooling                                   2.514***
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                                  0.321**
#                                          2. Spouse worked last year                                      0.078**
#                                          3. Both worked last year                                        0.113**
# Panel E. Fertility                       1. Number of children living in same household                 -0.39***
#                                          2. Has a child living in same household                         -0.067
#                                          3. Number of children living in same household,...            -0.371***
#                                          4. Has a child living in same household, only i...               0.007
#                                          5. Is a single parent                                            0.007
#                                          6. Is a never married, single parent                            -0.005
# Panel F. Residential location            1. Fraction of PUMA population from same countr...                 0.0
#                                          2. Fraction from same country of birth is above...              -0.011
#                                          3. Fraction of PUMA population with same primar...              -0.001
#                                          4. Fraction with same ancestry is above nationa...               0.031
#
#                                                                                              2SLS SE
# Panel                                    Dependent variable
# Panel A. Marital status                  1. Is currently married with spouse present           0.044
#                                          2. Is currently divorced                              0.020
#                                          3. Has ever married                                   0.028
# Panel B. Spouse’s nativity and ethnicity 1. Spouse English-speaking ability ordinal measure    0.140
#                                          2. Spouse is US-born                                  0.117
#                                          3. Spouse has the same country of birth               0.131
#                                          4. Spouse has the same ancestry                       0.114
# Panel C. Spouse’s age and education      1. Spouse age                                         0.421
#                                          2. Spouse years of schooling                          0.604
# Panel D. Spouse’s labor market outcomes  1. Spouse log(wages last year)                        0.125
#                                          2. Spouse worked last year                            0.032
#                                          3. Both worked last year                              0.045
# Panel E. Fertility                       1. Number of children living in same household        0.120
#                                          2. Has a child living in same household               0.044
#                                          3. Number of children living in same household,...    0.104
#                                          4. Has a child living in same household, only i...    0.027
#                                          5. Is a single parent                                 0.025
#                                          6. Is a never married, single parent                  0.018
# Panel F. Residential location            1. Fraction of PUMA population from same countr...    0.013
#                                          2. Fraction from same country of birth is above...    0.062
#                                          3. Fraction of PUMA population with same primar...    0.023
#                                          4. Fraction with same ancestry is above nationa...    0.062

# %% [markdown]
# The result is displayed in table 6. We can observe similar outcomes from the baseline model presented in table 4_. One exception is the English effect on the variable “spouse has the same primary ancestry”. In the baseline model, the effect is -0.181 and insignificant at 10% level. When we control for the interaction term, effect is -0.225 and significant at 5% level.

# %% [markdown]
# ### 6.3 English effect on outcome gap between immigrants and spouses

# %% [markdown]
# We extend the authors' analysis to other outcomes that we are interested in. We use the baseline model to investigate the gap of age, years of schooling, and income between spouses. These three gaps can be seen as a proxy for age closeness, education closeness and economic closeness between a couple. Apart from the bassline model, we also add controls for the immigrants’ level and their partners’ level of the dependent variables and observe the effect.

# %%
df_mat_R3 = df_mat
df_mat_R3['age'].replace('  ', np.nan, inplace=True)
df_mat_R3= df_mat_R3.dropna(subset=['age'])
df_mat_R3['spouseage'].replace('  ', np.nan, inplace=True)
df_mat_R3= df_mat_R3.dropna(subset=['spouseage'])
df_mat_R3['yrssch'].replace('  ', np.nan, inplace=True)
df_mat_R3= df_mat_R3.dropna(subset=['yrssch'])
df_mat_R3['spouseyrssch'].replace('  ', np.nan, inplace=True)
df_mat_R3= df_mat_R3.dropna(subset=['spouseyrssch'])
df_mat_R3['lnwagely'].replace('  ', np.nan, inplace=True)
df_mat_R3= df_mat_R3.dropna(subset=['lnwagely'])
df_mat_R3['spouselnwage'].replace('  ', np.nan, inplace=True)
df_mat_R3= df_mat_R3.dropna(subset=['spouselnwage'])


df_mat_R3["Wage_difference"] = abs(df_mat_R3["lnwagely"] - df_mat_R3["spouselnwage"])
df_mat_R3["Age_difference"] = abs(df_mat_R3["age"] - df_mat_R3["spouseage"])
df_mat_R3["Education_difference"] = abs(df_mat_R3["yrssch"] - df_mat_R3["spouseyrssch"])

list_mat_R3 = ["Wage_difference", "Age_difference", "Education_difference"    ]

result_mat_R3 = pd.DataFrame({"Dependent variable St": list_mat_R3})

get_tsls_result_table4(df_mat_R3, "Wage_difference", result_mat_R3,"lnwagely + spouselnwage" )
get_tsls_result_table4(df_mat_R3, "Education_difference", result_mat_R3, "yrssch +spouseyrssch ")
get_tsls_result_table4(df_mat_R3, "Age_difference", result_mat_R3,"spouseage" )

get_asterisk(result_mat_R3,"2SLS P Value", "2SLS")
result_mat_R3["2SLS Parameter (Full Sample)"] = (result_mat_R3["2SLS Parameter"].astype(str) + result_mat_R3["2SLS Sig. level"])
result_mat_R3=result_mat_R3.rename(columns={ "Dependent variable St":"Dependent variable", "2SLS SE": "SE (Full Sample)"})
result_mat_R3 = result_mat_R3.set_index('Dependent variable')
result_mat_R3= result_mat_R3[["2SLS Parameter (Full Sample)", "SE (Full Sample)"]]


# subset female sample 
df_mat_R3_female = df_mat_R3[df_mat_R3["female"] == 1]
result_mat_R3_female = pd.DataFrame({"Dependent variable St": list_mat_R3})

get_tsls_result_table4(df_mat_R3_female, "Wage_difference", result_mat_R3_female,"lnwagely + spouselnwage" )
get_tsls_result_table4(df_mat_R3_female, "Education_difference", result_mat_R3_female, "yrssch +spouseyrssch ")
get_tsls_result_table4(df_mat_R3_female, "Age_difference", result_mat_R3_female,"spouseage" )

get_asterisk(result_mat_R3_female,"2SLS P Value", "2SLS")
result_mat_R3_female["2SLS Parameter (Female Sample)"] = (result_mat_R3_female["2SLS Parameter"].astype(str) + result_mat_R3_female["2SLS Sig. level"])
result_mat_R3_female=result_mat_R3_female.rename(columns={ "Dependent variable St":"Dependent variable", "2SLS SE": "SE (Female Sample)"})
result_mat_R3_female = result_mat_R3_female.set_index('Dependent variable')
result_mat_R3_female= result_mat_R3_female[["2SLS Parameter (Female Sample)", "SE (Female Sample)"]]


# subset male sample 
df_mat_R3_male = df_mat_R3[df_mat_R3["female"] == 0]
result_mat_R3_male = pd.DataFrame({"Dependent variable St": list_mat_R3})

get_tsls_result_table4(df_mat_R3_male, "Wage_difference", result_mat_R3_male,"lnwagely + spouselnwage" )
get_tsls_result_table4(df_mat_R3_male, "Education_difference", result_mat_R3_male, "yrssch +spouseyrssch ")
get_tsls_result_table4(df_mat_R3_male, "Age_difference", result_mat_R3_male,"spouseage" )

get_asterisk(result_mat_R3_male,"2SLS P Value", "2SLS")
result_mat_R3_male["2SLS Parameter (Male Sample)"] = (result_mat_R3_male["2SLS Parameter"].astype(str) + result_mat_R3_male["2SLS Sig. level"])
result_mat_R3_male=result_mat_R3_male.rename(columns={ "Dependent variable St":"Dependent variable", "2SLS SE": "SE (Male Sample)"})
result_mat_R3_male = result_mat_R3_male.set_index('Dependent variable')
result_mat_R3_male= result_mat_R3_male[["2SLS Parameter (Male Sample)", "SE (Male Sample)"]]


result_mat_R3 = pd.merge(result_mat_R3, result_mat_R3_female,
                        left_on=['Dependent variable'], right_on = ['Dependent variable'], how = 'left')
result_mat_R3 = pd.merge(result_mat_R3, result_mat_R3_male,
                        left_on=['Dependent variable'], right_on = ['Dependent variable'], how = 'left')
# Out:
# Wage_difference
# Education_difference
# Age_difference
# /Users/chingfungchow/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# Wage_difference
# Education_difference
# Age_difference
# Wage_difference
# Education_difference
# Age_difference

# %%
print("Table 7 — English effect on the outcome gap with spouse")
result_mat_R3
# Out:
# Table 7 — English effect on the outcome gap with spouse
#                      2SLS Parameter (Full Sample)  SE (Full Sample)  \
# Dependent variable
# Wage_difference                           0.199**             0.083
# Age_difference                             0.216              0.269
# Education_difference                    -0.696***             0.130
#
#                      2SLS Parameter (Female Sample)  SE (Female Sample)  \
# Dependent variable
# Wage_difference                              0.094                0.062
# Age_difference                               0.247                0.273
# Education_difference                        -0.359*               0.202
#
#                      2SLS Parameter (Male Sample)  SE (Male Sample)
# Dependent variable
# Wage_difference                          0.213***             0.060
# Age_difference                             0.142              0.205
# Education_difference                    -1.057***             0.213

# %% [markdown]
# From the results we know that English level does not inflict significant effects on age and economic closeness. But it affects education closeness significantly. A simple explanation can be offered: English skills have a significant effect on communications and consequently exchanges of ideas. The cost of communication decreases if one’s English level is better. As a result, immigrants will consume more intelligence closeness.
#
#
# Suppose the three kinds of closeness are among the goods in deciding the utility of marriage (other goods will be, for example, the appearance of the partner). To consume education or intelligence closeness, one has to pay for the effort of communication. An increase in English level lowers the cost for communication, so the relative price of intelligence level closeness decrease. If intelligence closeness is not a Giffen good, then more of it will be consumed. However when it comes to age closeness or economic closeness, the increase of English level has no effect on the cost of these two goods. That explains why the English skill effects on the age gap and income gap are not significant. We can also observe that the magnitude of English effect is much stronger for male than for female immigrants. The differential can probably be explained by different utility curves of marriage between females and males.

# %% [markdown]
# ---
# # 7. Conclusion
# ---

# %% [markdown]
# The benchmark investigates the relationships between English proficiency and some social aspects of an immigrants in the US. The authors choose the age of arrival as the instrument to control for omitted variables bias and reverse causality problems. Although some doubts call for attention regarding endogeneity issues (section 6.1), nevertheless we still have theoretical reasons to retain the IV approach proposed by the benchmark. The IV results pass a lot of robustness checks (section 5.2 & 6.2). It is clearly demonstrated that English proficiency causes increases in certain outcomes, especially some marital and fertility outcomes (section 5.1 & 6.3). However, we have seen the conceptual pitfalls of the benchmark.
#
# The outcomes might not be satisfactory measurements for the level of social assimilation, despite being social outcomes. Some outcomes do not imply the degree of integration. That significantly limits the policy implications of the paper. We agree with most theses with the benchmark but differ in conceptual issues. As the aim of this replication paper is not to explore theories in immigration and population economics, we leave the project of defining good measurements for social assimilations to future researchers.

# %% [markdown]
# ---
# # 8. References
# ---

# %% [markdown]
# * **Bleakley, Hoyt, and Chin, Aimee**. 2010. Age at arrival, English proficiency, and social assimilation among US immigrants. *American Economic Journal: Applied Economics*, 2(1), 165-92.
#
#
# * **Duncan, Brian, and Stephen J. Trejo**. 2007. “Ethnic Identification, Intermarriage, and Unmeasured Progress by Mexican Americans.” In *Mexican Immigration to the United States*, ed. George J. Borjas, 229–67. Chicago, IL: University of Chicago Press and National Bureau of Economic Research.
#
#
# * **Funkhouser, Edward, and Fernando A. Ramos**. 1993. “The Choice of Migration Destination: Dominican and Cuban Immigrants to the Mainland United States and Puerto Rico.” *International Migration Review*, 27(3): 537–56.
#
#
# * **Lenneberg, Eric**. 1967. *Biological foundations of language*. New York (N.Y.): Wiley.
#
#
# * **Morris, Charles.**. 1967. *Foundations of the theory of signs* (International encyclopedia of unified science 1/2). University of Chicago press.
#
#
# * **Sorenson, Ann Marie**. 1988. “The Fertility and Language Characteristics of Mexican-American and Non-Hispanic Husbands and Wives.” *Sociological Quarterly*, 29(1): 111–30.
#
#
# * **Stevens, Gillian, and Gray Swicegood**. 1987. “The Linguistic Context of Ethnic Endogamy.” *American Sociological Review*, 52(1): 73–82.
#
#
# * **Swicegood, Gray, Frank D. Bean, Elizabeth Hervey Stephen, and Wolfgang Opitz**. 1988. “Language Usage and Fertility in Mexican-Origin Population of the United States.” *Demography*, 25(1): 17–33.
#
#
# * **Toussaint-Comeau, Maude, and Sherrie L. W. Rhine**. 2004. “Tenure Choice with Location Selection: The Case of Hispanic Neighborhoods in Chicago.” *Contemporary Economic Policy*, 22(1): 95–110.
#
#
# * **Wittgenstein, Ludwig**. 1968. *Philosophical investigations* (Repr. ed.). Oxford: Blackwell.
